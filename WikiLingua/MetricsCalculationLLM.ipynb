# %% [markdown]
# # Metrics calculation (LLM)

# %%
import pandas as pd
# summary_dataset = pd.read_csv("summary_dataset_with_bertscore.csv")
# columns = [column for column in summary_dataset.columns if "bertscore" not in column] 
# print(columns)
# summary_dataset = summary_dataset[columns]
# summary_dataset.to_csv("summary_dataset.csv", index=False)
# summary_dataset = pd.read_csv("summary_dataset.csv")
# summary_dataset.head()

# %%
summary_dataset = pd.read_csv("summary_dataset_with_bertscore_bleu_rouge_meteor_indexed.csv")
summary_dataset = summary_dataset.rename(columns={"Unnamed: 0": "Ind"})
import random

random.seed(43)
indices_for_evaluation = random.sample(range(0, len(summary_dataset)), 55)
indices_for_evaluation = sorted(indices_for_evaluation)
summary_dataset = summary_dataset[summary_dataset["Ind"].isin(indices_for_evaluation)]

# %%
summary_files = [
    "llama_7b_predictions.csv",
    "starling_predictions.csv",
    "yagpt_predictions.csv",
    "yagpt3_predictions.csv"
]

llm_data = pd.DataFrame()
for summary_file in summary_files:
    model_name = summary_file.split(".")[0]
    df = pd.read_csv(summary_file)[[model_name]]
    llm_data = pd.concat([llm_data, df], axis=1)

llm_data.head()
# Out:
#                                 llama_7b_predictions  \
# 0  Чистите зубы каждый день, пользовайтесь зубной...
# 1  После доставки травы домой ее следует подготов...
# 2  Ваши руки - ваше сокровище, ухаживайте за ними...
# 3  Используйте посудомоечную машину для стирки од...
# 4  Записывайте сны сразу после пробуждения, чтобы...
#
#                                 starling_predictions  \
# 0  Для сохранения белизны и здоровья зубов важно ...
# 1  После приобретения травы, её необходимо промыт...
# 2  Важнейшая инструкция для ухода за руками и их ...
# 3  Важно учить детей умению стирки и прививать им...
# 4  Сны - это частый явление, но часто трудно запо...
#
#                                    yagpt_predictions  \
# 0  - Чистить зубы каждый день, использовать зубну...
# 1  К сожалению, я не могу ничего сказать об этом....
# 2  - Руки являются важным инструментом для моделе...
# 3  - Задача пользователя - генерировать короткий ...
# 4  - Все люди видят сны, но часто забывают их.\n-...
#
#                                   yagpt3_predictions
# 0  Для поддержания здоровья зубов и предотвращени...
# 1  К сожалению, я не могу ничего сказать об этом....
# 2  Автор текста призывает заботиться о руках, пос...
# 3  Нужно положить грязную одежду в стиральную маш...
# 4  Всем снятся сны, но не всегда их удаётся запом...

# %%
summary_dataset = pd.concat([summary_dataset, llm_data.set_index(summary_dataset.index)], axis=1)
summary_dataset = summary_dataset[[column for column in summary_dataset.columns if "bertscore" not in column and "rouge" not in column and "meteor" not in column]]
summary_dataset = summary_dataset[summary_dataset["yagpt_predictions"] != "К сожалению, я не могу ничего сказать об этом. Давайте сменим тему?"]
summary_dataset.head()
print("Total: ", len(summary_dataset))
# Out:
# Total:  51

# %% [markdown]
# ## BERTScore

# %%
from evaluate import load
bertscore = load("bertscore")
files = [
    "mbart_predictions.txt",
    "mt5_predictions.txt",
    "summarunner_predictions.txt",
    "llama_7b_predictions.csv",
    "starling_predictions.csv",
    "yagpt_predictions.csv",
    "yagpt3_predictions.csv"
]

# %%
results = {}
references = list(summary_dataset["summary"])
for filename in files:
    predictions_field = filename.split(".")[0]
    predictions = list(summary_dataset[predictions_field])
    results[predictions_field] = bertscore.compute(predictions=predictions, references=references, lang="ru", verbose=True, model_type="microsoft/mdeberta-v3-base", nthreads=16, batch_size=16, use_fast_tokenizer=False)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364215.17 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364215.30 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364215.44 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364215.73 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364216.11 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364216.39 seconds, 0.00 sentences/sec
# calculating scores...
# computing bert embedding.
#   0%|          | 0/7 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/4 [00:00<?, ?it/s]
# done in 364216.68 seconds, 0.00 sentences/sec

# %%
data_keys = list(results.keys())
for data_key in data_keys:
    old_keys = list(results[data_key].keys())
    for old_metric_key in old_keys:
        results[data_key][f"{data_key}_bertscore_" + old_metric_key] = results[data_key].pop(old_metric_key)

# %%
print(results[filename.split(".")[0]].keys())
print(len(results[filename.split(".")[0]]))
# Out:
# dict_keys(['yagpt3_predictions_bertscore_precision', 'yagpt3_predictions_bertscore_recall', 'yagpt3_predictions_bertscore_f1', 'yagpt3_predictions_bertscore_hashcode'])
# 4

# %%
print(len(results[filename.split(".")[0]][f"{filename.split('.')[0]}_bertscore_precision"]))
# Out:
# 51

# %%
new_data = {}
for data_key in results.keys():
    for metric_key in results[data_key].keys():
        if "hashcode" in metric_key:
            continue
        new_data[metric_key] = pd.Series(results[data_key][metric_key])
new_data_df = pd.DataFrame(new_data)
new_data_df.head()
# Out:
#    mbart_predictions_bertscore_precision  mbart_predictions_bertscore_recall  \
# 0                               0.631593                            0.624381
# 1                               0.644282                            0.575288
# 2                               0.681743                            0.589087
# 3                               0.631319                            0.656633
# 4                               0.595945                            0.639990
#
#    mbart_predictions_bertscore_f1  mt5_predictions_bertscore_precision  \
# 0                        0.627966                             0.673249
# 1                        0.607833                             0.642150
# 2                        0.632037                             0.681641
# 3                        0.643727                             0.620151
# 4                        0.617182                             0.614952
#
#    mt5_predictions_bertscore_recall  mt5_predictions_bertscore_f1  \
# 0                          0.605494                      0.637577
# 1                          0.577963                      0.608368
# 2                          0.586275                      0.630371
# 3                          0.616955                      0.618549
# 4                          0.591488                      0.602992
#
#    summarunner_predictions_bertscore_precision  \
# 0                                     0.687089
# 1                                     0.676075
# 2                                     0.641098
# 3                                     0.652692
# 4                                     0.594532
#
#    summarunner_predictions_bertscore_recall  \
# 0                                  0.689886
# 1                                  0.680641
# 2                                  0.658043
# 3                                  0.708193
# 4                                  0.699398
#
#    summarunner_predictions_bertscore_f1  \
# 0                              0.688485
# 1                              0.678350
# 2                              0.649460
# 3                              0.679311
# 4                              0.642715
#
#    llama_7b_predictions_bertscore_precision  ...  \
# 0                                  0.726297  ...
# 1                                  0.635880  ...
# 2                                  0.628046  ...
# 3                                  0.552914  ...
# 4                                  0.588521  ...
#
#    llama_7b_predictions_bertscore_f1  \
# 0                           0.744807
# 1                           0.656465
# 2                           0.661089
# 3                           0.623575
# 4                           0.662679
#
#    starling_predictions_bertscore_precision  \
# 0                                  0.643891
# 1                                  0.592378
# 2                                  0.609980
# 3                                  0.603925
# 4                                  0.587893
#
#    starling_predictions_bertscore_recall  starling_predictions_bertscore_f1  \
# 0                               0.736579                           0.687123
# 1                               0.669815                           0.628721
# 2                               0.653202                           0.630851
# 3                               0.722020                           0.657713
# 4                               0.704453                           0.640917
#
#    yagpt_predictions_bertscore_precision  yagpt_predictions_bertscore_recall  \
# 0                               0.647951                            0.749931
# 1                               0.605613                            0.660121
# 2                               0.640942                            0.676423
# 3                               0.649337                            0.715555
# 4                               0.608653                            0.678829
#
#    yagpt_predictions_bertscore_f1  yagpt3_predictions_bertscore_precision  \
# 0                        0.695221                                0.668113
# 1                        0.631693                                0.608544
# 2                        0.658205                                0.638269
# 3                        0.680840                                0.577001
# 4                        0.641828                                0.586071
#
#    yagpt3_predictions_bertscore_recall  yagpt3_predictions_bertscore_f1
# 0                             0.784760                         0.721754
# 1                             0.651451                         0.629267
# 2                             0.686210                         0.661372
# 3                             0.686377                         0.626954
# 4                             0.746065                         0.656461
#
# [5 rows x 21 columns]

# %%
new_summary_dataset = pd.concat([summary_dataset, new_data_df.set_index(summary_dataset.index)], axis=1)
new_summary_dataset.head()
print(len(new_summary_dataset))
# Out:
# 51

# %%
summary_dataset = pd.DataFrame(new_summary_dataset)
del new_summary_dataset

# %%
summary_dataset.head()
print(len(summary_dataset))
# Out:
# 51

# %%
from statistics import mean 
from collections import defaultdict
score_stats = defaultdict(dict) if (not "score_stats" in locals() and not "score_stats" in globals()) else score_stats
for filename in files:
    predictions_field = filename.split(".")[0]
    
    mean_f1 = mean(results[predictions_field][f"{predictions_field}_bertscore_f1"])
    var_f1 = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_bertscore_f1"])) - mean_f1 ** 2
    
    mean_precision = mean(results[predictions_field][f"{predictions_field}_bertscore_precision"])
    var_precision = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_bertscore_precision"])) - mean_precision ** 2
    
    mean_recall = mean(results[predictions_field][f"{predictions_field}_bertscore_recall"])
    var_recall = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_bertscore_recall"])) - mean_recall ** 2
    
    score_stats[predictions_field].update({"mean_precision": mean_precision, "var_precision": var_precision, "mean_recall": mean_recall, "var_recall": var_recall, "mean_f1": mean_f1, "var_f1": var_f1})
print(dict(score_stats))
# Out:
# {'mbart_predictions': {'mean_precision': 0.6136284266032425, 'var_precision': 0.002562404920058825, 'mean_recall': 0.6459829117737564, 'var_recall': 0.0020065185461710655, 'mean_f1': 0.6278165169790679, 'var_f1': 0.0014819173965948673}, 'mt5_predictions': {'mean_precision': 0.6229039161813026, 'var_precision': 0.002883070243606789, 'mean_recall': 0.5968168857050877, 'var_recall': 0.001236734393415706, 'mean_f1': 0.6083403989380481, 'var_f1': 0.0013447706139774196}, 'summarunner_predictions': {'mean_precision': 0.6202631779745513, 'var_precision': 0.002442860837790939, 'mean_recall': 0.6661550426015667, 'var_recall': 0.001323556002591153, 'mean_f1': 0.6411289011730867, 'var_f1': 0.0012757973201810158}, 'llama_7b_predictions': {'mean_precision': 0.6178074286264532, 'var_precision': 0.0028896956557149522, 'mean_recall': 0.7163438925556108, 'var_recall': 0.0022519779464809098, 'mean_f1': 0.6624223227594414, 'var_f1': 0.002046067511045413}, 'starling_predictions': {'mean_precision': 0.5978781504958284, 'var_precision': 0.0029647872101712935, 'mean_recall': 0.6970196529930713, 'var_recall': 0.0015935245315422675, 'mean_f1': 0.6426460929945403, 'var_f1': 0.001885198793456333}, 'yagpt_predictions': {'mean_precision': 0.6221118861553716, 'var_precision': 0.002084477791294781, 'mean_recall': 0.7050818216566946, 'var_recall': 0.002066429417159732, 'mean_f1': 0.6602372480373756, 'var_f1': 0.0016432239276672478}, 'yagpt3_predictions': {'mean_precision': 0.6097682504092946, 'var_precision': 0.001972133741048543, 'mean_recall': 0.7128314504436418, 'var_recall': 0.0020629717548513726, 'mean_f1': 0.6565567757569107, 'var_f1': 0.0015918095719929526}}

# %%
results.keys()
# Out:
# dict_keys(['mbart_predictions', 'mt5_predictions', 'summarunner_predictions', 'llama_7b_predictions', 'starling_predictions', 'yagpt_predictions', 'yagpt3_predictions'])

# %%
stats_pd = pd.DataFrame(score_stats)

# %%
stats_pd.head(None)
# Out:
#                 mbart_predictions  mt5_predictions  summarunner_predictions  \
# mean_precision           0.613628         0.622904                 0.620263
# var_precision            0.002562         0.002883                 0.002443
# mean_recall              0.645983         0.596817                 0.666155
# var_recall               0.002007         0.001237                 0.001324
# mean_f1                  0.627817         0.608340                 0.641129
# var_f1                   0.001482         0.001345                 0.001276
#
#                 llama_7b_predictions  starling_predictions  yagpt_predictions  \
# mean_precision              0.617807              0.597878           0.622112
# var_precision               0.002890              0.002965           0.002084
# mean_recall                 0.716344              0.697020           0.705082
# var_recall                  0.002252              0.001594           0.002066
# mean_f1                     0.662422              0.642646           0.660237
# var_f1                      0.002046              0.001885           0.001643
#
#                 yagpt3_predictions
# mean_precision            0.609768
# var_precision             0.001972
# mean_recall               0.712831
# var_recall                0.002063
# mean_f1                   0.656557
# var_f1                    0.001592

# %%
summary_dataset.to_csv("summary_dataset_with_bertscore.csv", index=False)

# %%
len(summary_dataset)
# Out:
# 51

# %% [markdown]
# ## BLEU

# %%
import razdel
from evaluate import load
from tqdm import tqdm
import nltk

# results = {}
bleu = load('bleu')
references = list(summary_dataset["summary"])

def a(x):
    tokens = list(razdel.tokenize(x))
    return [_.text for _ in tokens]
    # return x.split()

for filename in files:
    predictions_field = filename.split(".")[0]
    predictions = list(summary_dataset[predictions_field])
    # results[predictions_field] = rouge.compute(predictions=predictions, references=references, use_aggregator=False, tokenizer=lambda x : list(razdel.tokenize(x)))
    results[predictions_field]["bleu"] = []
    for ref, pred in tqdm(zip(references, predictions)):
        bl = bleu.compute(predictions=[pred], references=[ref], tokenizer=a, smooth=True)
        # bl = nltk.translate.bleu(pred, ref)
        results[predictions_field]["bleu"].append(bl["bleu"])
# Out:
# 51it [00:00, 648.19it/s]
# 51it [00:00, 687.36it/s]
# 51it [00:00, 649.74it/s]
# 51it [00:00, 571.67it/s]
# 51it [00:00, 569.43it/s]
# 51it [00:00, 581.20it/s]
# 51it [00:00, 580.70it/s]

# %%
data_keys = list(results.keys())
print(data_keys)
for data_key in data_keys:
    old_keys = list(results[data_key].keys())
    print(old_keys)
    for old_metric_key in old_keys:
        results[data_key][f"{data_key}_" + old_metric_key] = results[data_key].pop(old_metric_key)
# Out:
# ['mbart_predictions', 'mt5_predictions', 'summarunner_predictions', 'llama_7b_predictions', 'starling_predictions', 'yagpt_predictions', 'yagpt3_predictions']
# ['mbart_predictions_bertscore_precision', 'mbart_predictions_bertscore_recall', 'mbart_predictions_bertscore_f1', 'mbart_predictions_bertscore_hashcode', 'bleu']
# ['mt5_predictions_bertscore_precision', 'mt5_predictions_bertscore_recall', 'mt5_predictions_bertscore_f1', 'mt5_predictions_bertscore_hashcode', 'bleu']
# ['summarunner_predictions_bertscore_precision', 'summarunner_predictions_bertscore_recall', 'summarunner_predictions_bertscore_f1', 'summarunner_predictions_bertscore_hashcode', 'bleu']
# ['llama_7b_predictions_bertscore_precision', 'llama_7b_predictions_bertscore_recall', 'llama_7b_predictions_bertscore_f1', 'llama_7b_predictions_bertscore_hashcode', 'bleu']
# ['starling_predictions_bertscore_precision', 'starling_predictions_bertscore_recall', 'starling_predictions_bertscore_f1', 'starling_predictions_bertscore_hashcode', 'bleu']
# ['yagpt_predictions_bertscore_precision', 'yagpt_predictions_bertscore_recall', 'yagpt_predictions_bertscore_f1', 'yagpt_predictions_bertscore_hashcode', 'bleu']
# ['yagpt3_predictions_bertscore_precision', 'yagpt3_predictions_bertscore_recall', 'yagpt3_predictions_bertscore_f1', 'yagpt3_predictions_bertscore_hashcode', 'bleu']

# %%
print(results[filename.split(".")[0]].keys())
# Out:
# dict_keys(['yagpt3_predictions_yagpt3_predictions_bertscore_precision', 'yagpt3_predictions_yagpt3_predictions_bertscore_recall', 'yagpt3_predictions_yagpt3_predictions_bertscore_f1', 'yagpt3_predictions_yagpt3_predictions_bertscore_hashcode', 'yagpt3_predictions_bleu'])

# %%
print(results[filename.split(".")[0]][f"{filename.split('.')[0]}_bleu"])
# Out:
# [0.026750816423785816, 0.03202289411234805, 0.038028422576808, 0.014206586137818344, 0.018042471224739884, 0.030529807855792186, 0.023915238684182282, 0.045680352631985464, 0.031983487823250265, 0.042020425849160166, 0.01408357381457623, 0.029096451811953992, 0.041134845763007126, 0.02645541924746324, 0.011302915099255477, 0.01648193227038116, 0.0584192288329162, 0.02664094361367871, 0.021156719190824593, 0.03200512175383545, 0.014063537945480188, 0.02744917703739533, 0.057446387286086247, 0.01879243431596414, 0.02289355938731725, 0.06108557268562174, 0.02465448790945244, 0.020448357708217915, 0.029883432477608395, 0.019996667521972298, 0.032739755503851865, 0.014018080775451417, 0.023615074687245826, 0.02160090509900319, 0.016470076454180194, 0.03225641780355764, 0.04124160134389764, 0.01909058567104395, 0.035621546005625296, 0.023199901472763716, 0.02106055451080167, 0.06616259609591661, 0.011079891322284109, 0.020578146917622196, 0.03946507878446118, 0.04899017558375205, 0.016851206781117765, 0.06978423773483027, 0.07612239599240517, 0.020322208407840586, 0.02294358624721041]

# %%
new_data = {}
for data_key in results.keys():
    for metric_key in results[data_key].keys():
        if not "bleu" in metric_key:
            continue
        new_data[metric_key] = pd.Series(results[data_key][metric_key])
new_data_df = pd.DataFrame(new_data)
new_data_df.head()
# Out:
#    mbart_predictions_bleu  mt5_predictions_bleu  summarunner_predictions_bleu  \
# 0                0.017496              0.005383                      0.060654
# 1                0.016922              0.011950                      0.075167
# 2                0.023233              0.002937                      0.036801
# 3                0.066542              0.058565                      0.039209
# 4                0.051349              0.049504                      0.029521
#
#    llama_7b_predictions_bleu  starling_predictions_bleu  \
# 0                   0.042217                   0.024531
# 1                   0.025555                   0.019571
# 2                   0.030596                   0.032465
# 3                   0.014875                   0.024450
# 4                   0.017103                   0.015920
#
#    yagpt_predictions_bleu  yagpt3_predictions_bleu
# 0                0.019532                 0.026751
# 1                0.015097                 0.032023
# 2                0.032633                 0.038028
# 3                0.028370                 0.014207
# 4                0.017944                 0.018042

# %%
len(new_data_df)
# Out:
# 51

# %%
new_summary_dataset = pd.concat([summary_dataset, new_data_df.set_index(summary_dataset.index)], axis=1)
new_summary_dataset.head()
# Out:
#      Ind                              title  \
# 156  156  wikilingua_multilingual-val-36988
# 400  400  wikilingua_multilingual-val-37232
# 472  472  wikilingua_multilingual-val-37304
# 500  500  wikilingua_multilingual-val-37332
# 501  501  wikilingua_multilingual-val-37333
#
#                                                   text  \
# 156  Лучший путь поддержания здоровья зубов и предо...
# 400  Ваши руки - ваше сокровище, ухаживайте за ними...
# 472  Или поместите ее в посудомоечную машину. Когда...
# 500  Все люди видят сны, и часто не по одному за но...
# 501  . Прежде всего вам необходимо начинать поиски ...
#
#                                                summary  \
# 156  Чистите зубы и используйте зубную нить. Не заб...
# 400  Чрезмерный уход за руками. Не бросайте свою ос...
# 472  После еды сложите посуду в раковину и споласки...
# 500  Ведите дневник сновидений. Делайте записи в дн...
# 501  Найдите свое определение любви Учитывайте разн...
#
#                                      mbart_predictions  \
# 156  Российские стоматологи рассказали о том, как з...
# 400  На этой неделе мы расскажем о том, как правиль...
# 472  В сегодняшнем обзоре мы расскажем о том, как п...
# 500  В преддверии ночи, когда вы проснетесь из-за с...
# 501  В сегодняшнем материале мы поговорим о том, ка...
#
#                                        mt5_predictions  \
# 156  Существует множество способов защитить зубы от...
# 400  Если вы когда-нибудь станете топ моделью, то н...
# 472    Вы можете вывести пятна из стиральной машины.\n
# 500  Сношения во сне могут помочь вам лучше понимат...
# 501  Любовь - это явление, которое можно описать ка...
#
#                                summarunner_predictions mbart_predictions_bleu  \
# 156  выберите синюю водолазку и темный блеск для гу...               0.017496
# 400  регулярно мажьте руки питательным кремом. если...               0.016922
# 472  когда вы заметите, что она заполнена, запустит...               0.023233
# 500  записывайте все мельчайшие детали, а также фик...               0.066542
# 501  в контексте романтической любви многие нередко...               0.051349
#
#      mt5_predictions_bleu  summarunner_predictions_bleu  ...  \
# 156              0.005383                      0.060654  ...
# 400              0.011950                      0.075167  ...
# 472              0.002937                      0.036801  ...
# 500              0.058565                      0.039209  ...
# 501              0.049504                      0.029521  ...
#
#     yagpt3_predictions_bertscore_precision  \
# 156                               0.668113
# 400                               0.608544
# 472                               0.638269
# 500                               0.577001
# 501                               0.586071
#
#     yagpt3_predictions_bertscore_recall yagpt3_predictions_bertscore_f1  \
# 156                            0.784760                        0.721754
# 400                            0.651451                        0.629267
# 472                            0.686210                        0.661372
# 500                            0.686377                        0.626954
# 501                            0.746065                        0.656461
#
#     mbart_predictions_bleu  mt5_predictions_bleu  \
# 156               0.017496              0.005383
# 400               0.016922              0.011950
# 472               0.023233              0.002937
# 500               0.066542              0.058565
# 501               0.051349              0.049504
#
#      summarunner_predictions_bleu  llama_7b_predictions_bleu  \
# 156                      0.060654                   0.042217
# 400                      0.075167                   0.025555
# 472                      0.036801                   0.030596
# 500                      0.039209                   0.014875
# 501                      0.029521                   0.017103
#
#      starling_predictions_bleu  yagpt_predictions_bleu  \
# 156                   0.024531                0.019532
# 400                   0.019571                0.015097
# 472                   0.032465                0.032633
# 500                   0.024450                0.028370
# 501                   0.015920                0.017944
#
#      yagpt3_predictions_bleu
# 156                 0.026751
# 400                 0.032023
# 472                 0.038028
# 500                 0.014207
# 501                 0.018042
#
# [5 rows x 42 columns]

# %%
print(len(new_summary_dataset), len(summary_dataset))
# Out:
# 51 51

# %%
summary_dataset = pd.DataFrame(new_summary_dataset)
del new_summary_dataset

# %%
summary_dataset.head()
# Out:
#      Ind                              title  \
# 156  156  wikilingua_multilingual-val-36988
# 400  400  wikilingua_multilingual-val-37232
# 472  472  wikilingua_multilingual-val-37304
# 500  500  wikilingua_multilingual-val-37332
# 501  501  wikilingua_multilingual-val-37333
#
#                                                   text  \
# 156  Лучший путь поддержания здоровья зубов и предо...
# 400  Ваши руки - ваше сокровище, ухаживайте за ними...
# 472  Или поместите ее в посудомоечную машину. Когда...
# 500  Все люди видят сны, и часто не по одному за но...
# 501  . Прежде всего вам необходимо начинать поиски ...
#
#                                                summary  \
# 156  Чистите зубы и используйте зубную нить. Не заб...
# 400  Чрезмерный уход за руками. Не бросайте свою ос...
# 472  После еды сложите посуду в раковину и споласки...
# 500  Ведите дневник сновидений. Делайте записи в дн...
# 501  Найдите свое определение любви Учитывайте разн...
#
#                                      mbart_predictions  \
# 156  Российские стоматологи рассказали о том, как з...
# 400  На этой неделе мы расскажем о том, как правиль...
# 472  В сегодняшнем обзоре мы расскажем о том, как п...
# 500  В преддверии ночи, когда вы проснетесь из-за с...
# 501  В сегодняшнем материале мы поговорим о том, ка...
#
#                                        mt5_predictions  \
# 156  Существует множество способов защитить зубы от...
# 400  Если вы когда-нибудь станете топ моделью, то н...
# 472    Вы можете вывести пятна из стиральной машины.\n
# 500  Сношения во сне могут помочь вам лучше понимат...
# 501  Любовь - это явление, которое можно описать ка...
#
#                                summarunner_predictions mbart_predictions_bleu  \
# 156  выберите синюю водолазку и темный блеск для гу...               0.017496
# 400  регулярно мажьте руки питательным кремом. если...               0.016922
# 472  когда вы заметите, что она заполнена, запустит...               0.023233
# 500  записывайте все мельчайшие детали, а также фик...               0.066542
# 501  в контексте романтической любви многие нередко...               0.051349
#
#      mt5_predictions_bleu  summarunner_predictions_bleu  ...  \
# 156              0.005383                      0.060654  ...
# 400              0.011950                      0.075167  ...
# 472              0.002937                      0.036801  ...
# 500              0.058565                      0.039209  ...
# 501              0.049504                      0.029521  ...
#
#     yagpt3_predictions_bertscore_precision  \
# 156                               0.668113
# 400                               0.608544
# 472                               0.638269
# 500                               0.577001
# 501                               0.586071
#
#     yagpt3_predictions_bertscore_recall yagpt3_predictions_bertscore_f1  \
# 156                            0.784760                        0.721754
# 400                            0.651451                        0.629267
# 472                            0.686210                        0.661372
# 500                            0.686377                        0.626954
# 501                            0.746065                        0.656461
#
#     mbart_predictions_bleu  mt5_predictions_bleu  \
# 156               0.017496              0.005383
# 400               0.016922              0.011950
# 472               0.023233              0.002937
# 500               0.066542              0.058565
# 501               0.051349              0.049504
#
#      summarunner_predictions_bleu  llama_7b_predictions_bleu  \
# 156                      0.060654                   0.042217
# 400                      0.075167                   0.025555
# 472                      0.036801                   0.030596
# 500                      0.039209                   0.014875
# 501                      0.029521                   0.017103
#
#      starling_predictions_bleu  yagpt_predictions_bleu  \
# 156                   0.024531                0.019532
# 400                   0.019571                0.015097
# 472                   0.032465                0.032633
# 500                   0.024450                0.028370
# 501                   0.015920                0.017944
#
#      yagpt3_predictions_bleu
# 156                 0.026751
# 400                 0.032023
# 472                 0.038028
# 500                 0.014207
# 501                 0.018042
#
# [5 rows x 42 columns]

# %%
# from statistics import mean 
# from collections import defaultdict
# score_stats = defaultdict(dict) if (not "score_stats" in locals() and not "score_stats" in globals()) else score_stats
# for filename in files:
#     predictions_field = filename.split(".")[0]
#     mean_rouge1 = mean(results[predictions_field][f"{predictions_field}_rouge1"])
#     var_rouge1 = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rouge1"])) - mean_rouge1 ** 2
    
#     mean_rouge2 = mean(results[predictions_field][f"{predictions_field}_rouge2"])
#     var_rouge2 = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rouge2"])) - mean_rouge2 ** 2
    
#     mean_rougeL = mean(results[predictions_field][f"{predictions_field}_rougeL"])
#     var_rougeL = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rougeL"])) - mean_rougeL ** 2
    
#     mean_rougeLsum = mean(results[predictions_field][f"{predictions_field}_rougeLsum"])
#     var_rougeLsum = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rougeLsum"])) - mean_rougeLsum ** 2
#     score_stats[predictions_field].update({"mean_rouge1": mean_rouge1, "var_rouge1": var_rouge1, "mean_rouge2": mean_rouge2, "var_rouge2": var_rouge2, "mean_rougeL": mean_rougeL, "var_rougeL": var_rougeL, "mean_rougeLsum": mean_rougeLsum, "var_rougeLsum": var_rougeLsum})
# print(dict(score_stats))

# %%
# stats_pd = pd.DataFrame(score_stats)

# %%
# stats_pd.head(len(stats_pd))

# %%
summary_dataset.to_csv("summary_dataset_with_bertscore_bleu.csv", index=False)

# %%
len(summary_dataset)
# Out:
# 51

# %% [markdown]
# ## ROUGE

# %%
import pandas as pd
summary_dataset = pd.read_csv("summary_dataset_with_bertscore_bleu.csv")
files = [
    "mbart_predictions.txt",
    "mt5_predictions.txt",
    "summarunner_predictions.txt",
    "llama_7b_predictions.csv",
    "starling_predictions.csv",
    "yagpt_predictions.csv",
    "yagpt3_predictions.csv"
]

# %%
import razdel
from evaluate import load
# results = {}
rouge = load('rouge')
references = list(summary_dataset["summary"])

def a(x):
    tokens = list(razdel.tokenize(x))
    return [_.text for _ in tokens]
    # return x.split()

for filename in files:
    predictions_field = filename.split(".")[0]
    predictions = list(summary_dataset[predictions_field])
    # results[predictions_field] = rouge.compute(predictions=predictions, references=references, use_aggregator=False, tokenizer=lambda x : list(razdel.tokenize(x)))
    results[predictions_field] = rouge.compute(predictions=predictions, references=references, use_aggregator=False, tokenizer=a)

# %%
data_keys = list(results.keys())
for data_key in data_keys:
    old_keys = list(results[data_key].keys())
    for old_metric_key in old_keys:
        results[data_key][f"{data_key}_" + old_metric_key] = results[data_key].pop(old_metric_key)

# %%
print(results[filename.split(".")[0]].keys())
# Out:
# dict_keys(['yagpt3_predictions_rouge1', 'yagpt3_predictions_rouge2', 'yagpt3_predictions_rougeL', 'yagpt3_predictions_rougeLsum'])

# %%
print(len(results[filename.split(".")[0]][f"{filename.split('.')[0]}_rouge1"]))
# Out:
# 51

# %%
new_data = {}
for data_key in results.keys():
    for metric_key in results[data_key].keys():
        if "hashcode" in metric_key:
            continue
        new_data[metric_key] = pd.Series(results[data_key][metric_key])
new_data_df = pd.DataFrame(new_data)
new_data_df.head()
# Out:
#    mbart_predictions_rouge1  mbart_predictions_rouge2  \
# 0                  0.129032                  0.000000
# 1                  0.101695                  0.000000
# 2                  0.145455                  0.037736
# 3                  0.190476                  0.000000
# 4                  0.169492                  0.000000
#
#    mbart_predictions_rougeL  mbart_predictions_rougeLsum  \
# 0                  0.096774                     0.096774
# 1                  0.067797                     0.067797
# 2                  0.145455                     0.145455
# 3                  0.142857                     0.142857
# 4                  0.135593                     0.135593
#
#    mt5_predictions_rouge1  mt5_predictions_rouge2  mt5_predictions_rougeL  \
# 0                0.109091                0.037736                0.109091
# 1                0.142857                0.000000                0.142857
# 2                0.041667                0.000000                0.041667
# 3                0.095238                0.000000                0.095238
# 4                0.122449                0.000000                0.081633
#
#    mt5_predictions_rougeLsum  summarunner_predictions_rouge1  \
# 0                   0.109091                        0.225000
# 1                   0.142857                        0.282353
# 2                   0.041667                        0.222222
# 3                   0.095238                        0.196721
# 4                   0.081633                        0.228571
#
#    summarunner_predictions_rouge2  ...  starling_predictions_rougeL  \
# 0                        0.051282  ...                     0.135593
# 1                        0.072289  ...                     0.134831
# 2                        0.000000  ...                     0.161616
# 3                        0.000000  ...                     0.113208
# 4                        0.019417  ...                     0.115607
#
#    starling_predictions_rougeLsum  yagpt_predictions_rouge1  \
# 0                        0.135593                  0.202128
# 1                        0.112360                  0.179775
# 2                        0.161616                  0.234234
# 3                        0.113208                  0.176471
# 4                        0.127168                  0.153846
#
#    yagpt_predictions_rouge2  yagpt_predictions_rougeL  \
# 0                  0.021505                  0.159574
# 1                  0.000000                  0.112360
# 2                  0.018349                  0.144144
# 3                  0.040000                  0.176471
# 4                  0.000000                  0.123077
#
#    yagpt_predictions_rougeLsum  yagpt3_predictions_rouge1  \
# 0                     0.106383                   0.194286
# 1                     0.089888                   0.183333
# 2                     0.090090                   0.257426
# 3                     0.117647                   0.089552
# 4                     0.061538                   0.166667
#
#    yagpt3_predictions_rouge2  yagpt3_predictions_rougeL  \
# 0                   0.034682                   0.182857
# 1                   0.033898                   0.150000
# 2                   0.020202                   0.178218
# 3                   0.000000                   0.074627
# 4                   0.012987                   0.115385
#
#    yagpt3_predictions_rougeLsum
# 0                      0.125714
# 1                      0.083333
# 2                      0.217822
# 3                      0.059701
# 4                      0.128205
#
# [5 rows x 28 columns]

# %%
new_summary_dataset = pd.concat([summary_dataset, new_data_df.set_index(summary_dataset.index)], axis=1)
new_summary_dataset.head()
# Out:
#    Ind                              title  \
# 0  156  wikilingua_multilingual-val-36988
# 1  400  wikilingua_multilingual-val-37232
# 2  472  wikilingua_multilingual-val-37304
# 3  500  wikilingua_multilingual-val-37332
# 4  501  wikilingua_multilingual-val-37333
#
#                                                 text  \
# 0  Лучший путь поддержания здоровья зубов и предо...
# 1  Ваши руки - ваше сокровище, ухаживайте за ними...
# 2  Или поместите ее в посудомоечную машину. Когда...
# 3  Все люди видят сны, и часто не по одному за но...
# 4  . Прежде всего вам необходимо начинать поиски ...
#
#                                              summary  \
# 0  Чистите зубы и используйте зубную нить. Не заб...
# 1  Чрезмерный уход за руками. Не бросайте свою ос...
# 2  После еды сложите посуду в раковину и споласки...
# 3  Ведите дневник сновидений. Делайте записи в дн...
# 4  Найдите свое определение любви Учитывайте разн...
#
#                                    mbart_predictions  \
# 0  Российские стоматологи рассказали о том, как з...
# 1  На этой неделе мы расскажем о том, как правиль...
# 2  В сегодняшнем обзоре мы расскажем о том, как п...
# 3  В преддверии ночи, когда вы проснетесь из-за с...
# 4  В сегодняшнем материале мы поговорим о том, ка...
#
#                                      mt5_predictions  \
# 0  Существует множество способов защитить зубы от...
# 1  Если вы когда-нибудь станете топ моделью, то н...
# 2    Вы можете вывести пятна из стиральной машины.\n
# 3  Сношения во сне могут помочь вам лучше понимат...
# 4  Любовь - это явление, которое можно описать ка...
#
#                              summarunner_predictions  mbart_predictions_bleu  \
# 0  выберите синюю водолазку и темный блеск для гу...                0.017496
# 1  регулярно мажьте руки питательным кремом. если...                0.016922
# 2  когда вы заметите, что она заполнена, запустит...                0.023233
# 3  записывайте все мельчайшие детали, а также фик...                0.066542
# 4  в контексте романтической любви многие нередко...                0.051349
#
#    mt5_predictions_bleu  summarunner_predictions_bleu  ...  \
# 0              0.005383                      0.060654  ...
# 1              0.011950                      0.075167  ...
# 2              0.002937                      0.036801  ...
# 3              0.058565                      0.039209  ...
# 4              0.049504                      0.029521  ...
#
#   starling_predictions_rougeL starling_predictions_rougeLsum  \
# 0                    0.135593                       0.135593
# 1                    0.134831                       0.112360
# 2                    0.161616                       0.161616
# 3                    0.113208                       0.113208
# 4                    0.115607                       0.127168
#
#   yagpt_predictions_rouge1 yagpt_predictions_rouge2  yagpt_predictions_rougeL  \
# 0                 0.202128                 0.021505                  0.159574
# 1                 0.179775                 0.000000                  0.112360
# 2                 0.234234                 0.018349                  0.144144
# 3                 0.176471                 0.040000                  0.176471
# 4                 0.153846                 0.000000                  0.123077
#
#    yagpt_predictions_rougeLsum  yagpt3_predictions_rouge1  \
# 0                     0.106383                   0.194286
# 1                     0.089888                   0.183333
# 2                     0.090090                   0.257426
# 3                     0.117647                   0.089552
# 4                     0.061538                   0.166667
#
#    yagpt3_predictions_rouge2  yagpt3_predictions_rougeL  \
# 0                   0.034682                   0.182857
# 1                   0.033898                   0.150000
# 2                   0.020202                   0.178218
# 3                   0.000000                   0.074627
# 4                   0.012987                   0.115385
#
#    yagpt3_predictions_rougeLsum
# 0                      0.125714
# 1                      0.083333
# 2                      0.217822
# 3                      0.059701
# 4                      0.128205
#
# [5 rows x 70 columns]

# %%
summary_dataset = pd.DataFrame(new_summary_dataset)
del new_summary_dataset

# %%
summary_dataset.head()
# Out:
#    Ind                              title  \
# 0  156  wikilingua_multilingual-val-36988
# 1  400  wikilingua_multilingual-val-37232
# 2  472  wikilingua_multilingual-val-37304
# 3  500  wikilingua_multilingual-val-37332
# 4  501  wikilingua_multilingual-val-37333
#
#                                                 text  \
# 0  Лучший путь поддержания здоровья зубов и предо...
# 1  Ваши руки - ваше сокровище, ухаживайте за ними...
# 2  Или поместите ее в посудомоечную машину. Когда...
# 3  Все люди видят сны, и часто не по одному за но...
# 4  . Прежде всего вам необходимо начинать поиски ...
#
#                                              summary  \
# 0  Чистите зубы и используйте зубную нить. Не заб...
# 1  Чрезмерный уход за руками. Не бросайте свою ос...
# 2  После еды сложите посуду в раковину и споласки...
# 3  Ведите дневник сновидений. Делайте записи в дн...
# 4  Найдите свое определение любви Учитывайте разн...
#
#                                    mbart_predictions  \
# 0  Российские стоматологи рассказали о том, как з...
# 1  На этой неделе мы расскажем о том, как правиль...
# 2  В сегодняшнем обзоре мы расскажем о том, как п...
# 3  В преддверии ночи, когда вы проснетесь из-за с...
# 4  В сегодняшнем материале мы поговорим о том, ка...
#
#                                      mt5_predictions  \
# 0  Существует множество способов защитить зубы от...
# 1  Если вы когда-нибудь станете топ моделью, то н...
# 2    Вы можете вывести пятна из стиральной машины.\n
# 3  Сношения во сне могут помочь вам лучше понимат...
# 4  Любовь - это явление, которое можно описать ка...
#
#                              summarunner_predictions  mbart_predictions_bleu  \
# 0  выберите синюю водолазку и темный блеск для гу...                0.017496
# 1  регулярно мажьте руки питательным кремом. если...                0.016922
# 2  когда вы заметите, что она заполнена, запустит...                0.023233
# 3  записывайте все мельчайшие детали, а также фик...                0.066542
# 4  в контексте романтической любви многие нередко...                0.051349
#
#    mt5_predictions_bleu  summarunner_predictions_bleu  ...  \
# 0              0.005383                      0.060654  ...
# 1              0.011950                      0.075167  ...
# 2              0.002937                      0.036801  ...
# 3              0.058565                      0.039209  ...
# 4              0.049504                      0.029521  ...
#
#   starling_predictions_rougeL starling_predictions_rougeLsum  \
# 0                    0.135593                       0.135593
# 1                    0.134831                       0.112360
# 2                    0.161616                       0.161616
# 3                    0.113208                       0.113208
# 4                    0.115607                       0.127168
#
#   yagpt_predictions_rouge1 yagpt_predictions_rouge2  yagpt_predictions_rougeL  \
# 0                 0.202128                 0.021505                  0.159574
# 1                 0.179775                 0.000000                  0.112360
# 2                 0.234234                 0.018349                  0.144144
# 3                 0.176471                 0.040000                  0.176471
# 4                 0.153846                 0.000000                  0.123077
#
#    yagpt_predictions_rougeLsum  yagpt3_predictions_rouge1  \
# 0                     0.106383                   0.194286
# 1                     0.089888                   0.183333
# 2                     0.090090                   0.257426
# 3                     0.117647                   0.089552
# 4                     0.061538                   0.166667
#
#    yagpt3_predictions_rouge2  yagpt3_predictions_rougeL  \
# 0                   0.034682                   0.182857
# 1                   0.033898                   0.150000
# 2                   0.020202                   0.178218
# 3                   0.000000                   0.074627
# 4                   0.012987                   0.115385
#
#    yagpt3_predictions_rougeLsum
# 0                      0.125714
# 1                      0.083333
# 2                      0.217822
# 3                      0.059701
# 4                      0.128205
#
# [5 rows x 70 columns]

# %% [markdown]
# Посчитаем статистики для представления о качестве датасета

# %%
from statistics import mean 
from collections import defaultdict
score_stats = defaultdict(dict) if (not "score_stats" in locals() and not "score_stats" in globals()) else score_stats
for filename in files:
    predictions_field = filename.split(".")[0]
    mean_rouge1 = mean(results[predictions_field][f"{predictions_field}_rouge1"])
    var_rouge1 = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rouge1"])) - mean_rouge1 ** 2
    
    mean_rouge2 = mean(results[predictions_field][f"{predictions_field}_rouge2"])
    var_rouge2 = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rouge2"])) - mean_rouge2 ** 2
    
    mean_rougeL = mean(results[predictions_field][f"{predictions_field}_rougeL"])
    var_rougeL = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rougeL"])) - mean_rougeL ** 2
    
    mean_rougeLsum = mean(results[predictions_field][f"{predictions_field}_rougeLsum"])
    var_rougeLsum = mean(map(lambda x: x**2, results[predictions_field][f"{predictions_field}_rougeLsum"])) - mean_rougeLsum ** 2
    score_stats[predictions_field].update({"mean_rouge1": mean_rouge1, "var_rouge1": var_rouge1, "mean_rouge2": mean_rouge2, "var_rouge2": var_rouge2, "mean_rougeL": mean_rougeL, "var_rougeL": var_rougeL, "mean_rougeLsum": mean_rougeLsum, "var_rougeLsum": var_rougeLsum})
print(dict(score_stats))
# Out:
# {'mbart_predictions': {'mean_precision': 0.6136284266032425, 'var_precision': 0.002562404920058825, 'mean_recall': 0.6459829117737564, 'var_recall': 0.0020065185461710655, 'mean_f1': 0.6278165169790679, 'var_f1': 0.0014819173965948673, 'mean_rouge1': 0.17117003932067482, 'var_rouge1': 0.004341147921558534, 'mean_rouge2': 0.02344682199891833, 'var_rouge2': 0.0011444597245821816, 'mean_rougeL': 0.13289182462640708, 'var_rougeL': 0.002422151570893989, 'mean_rougeLsum': 0.13289182462640708, 'var_rougeLsum': 0.002422151570893989}, 'mt5_predictions': {'mean_precision': 0.6229039161813026, 'var_precision': 0.002883070243606789, 'mean_recall': 0.5968168857050877, 'var_recall': 0.001236734393415706, 'mean_f1': 0.6083403989380481, 'var_f1': 0.0013447706139774196, 'mean_rouge1': 0.12115537965951172, 'var_rouge1': 0.004318886772201885, 'mean_rouge2': 0.01688636431316882, 'var_rouge2': 0.0009999806910292405, 'mean_rougeL': 0.10811023400453072, 'var_rougeL': 0.0025408305074679956, 'mean_rougeLsum': 0.10811023400453072, 'var_rougeLsum': 0.0025408305074679956}, 'summarunner_predictions': {'mean_precision': 0.6202631779745513, 'var_precision': 0.002442860837790939, 'mean_recall': 0.6661550426015667, 'var_recall': 0.001323556002591153, 'mean_f1': 0.6411289011730867, 'var_f1': 0.0012757973201810158, 'mean_rouge1': 0.18815493017950222, 'var_rouge1': 0.003888411247850748, 'mean_rouge2': 0.02583488880387178, 'var_rouge2': 0.0008040357464434562, 'mean_rougeL': 0.15133532129377916, 'var_rougeL': 0.0021676664390451357, 'mean_rougeLsum': 0.15133532129377916, 'var_rougeLsum': 0.0021676664390451357}, 'llama_7b_predictions': {'mean_precision': 0.6178074286264532, 'var_precision': 0.0028896956557149522, 'mean_recall': 0.7163438925556108, 'var_recall': 0.0022519779464809098, 'mean_f1': 0.6624223227594414, 'var_f1': 0.002046067511045413, 'mean_rouge1': 0.18404810986895076, 'var_rouge1': 0.005549488951922157, 'mean_rouge2': 0.031596272990962605, 'var_rouge2': 0.0012819604218083276, 'mean_rougeL': 0.14269638782712746, 'var_rougeL': 0.003370777686644958, 'mean_rougeLsum': 0.14269638782712746, 'var_rougeLsum': 0.003370777686644958}, 'starling_predictions': {'mean_precision': 0.5978781504958284, 'var_precision': 0.0029647872101712935, 'mean_recall': 0.6970196529930713, 'var_recall': 0.0015935245315422675, 'mean_f1': 0.6426460929945403, 'var_f1': 0.001885198793456333, 'mean_rouge1': 0.16355392958408868, 'var_rouge1': 0.004343551417780856, 'mean_rouge2': 0.022256987700321546, 'var_rouge2': 0.0005709453941141093, 'mean_rougeL': 0.12881994742563774, 'var_rougeL': 0.0023169557201447206, 'mean_rougeLsum': 0.1255159474498046, 'var_rougeLsum': 0.0022256943447222857}, 'yagpt_predictions': {'mean_precision': 0.6221118861553716, 'var_precision': 0.002084477791294781, 'mean_recall': 0.7050818216566946, 'var_recall': 0.002066429417159732, 'mean_f1': 0.6602372480373756, 'var_f1': 0.0016432239276672478, 'mean_rouge1': 0.17375386886593694, 'var_rouge1': 0.003705177909264369, 'mean_rouge2': 0.0249180721178968, 'var_rouge2': 0.0006256438481420195, 'mean_rougeL': 0.14211638459294568, 'var_rougeL': 0.0025129727654574184, 'mean_rougeLsum': 0.10604729545512707, 'var_rougeLsum': 0.0020104411437816116}, 'yagpt3_predictions': {'mean_precision': 0.6097682504092946, 'var_precision': 0.001972133741048543, 'mean_recall': 0.7128314504436418, 'var_recall': 0.0020629717548513726, 'mean_f1': 0.6565567757569107, 'var_f1': 0.0015918095719929526, 'mean_rouge1': 0.1845047343290969, 'var_rouge1': 0.004084669016391623, 'mean_rouge2': 0.03539787941101373, 'var_rouge2': 0.0010108189958868675, 'mean_rougeL': 0.14239511112866218, 'var_rougeL': 0.00222487945334059, 'mean_rougeLsum': 0.13307337607546746, 'var_rougeLsum': 0.0020812017569313973}}

# %%
stats_pd = pd.DataFrame(score_stats)

# %%
stats_pd.head(len(stats_pd))
# Out:
#                 mbart_predictions  mt5_predictions  summarunner_predictions  \
# mean_precision           0.613628         0.622904                 0.620263
# var_precision            0.002562         0.002883                 0.002443
# mean_recall              0.645983         0.596817                 0.666155
# var_recall               0.002007         0.001237                 0.001324
# mean_f1                  0.627817         0.608340                 0.641129
# var_f1                   0.001482         0.001345                 0.001276
# mean_rouge1              0.171170         0.121155                 0.188155
# var_rouge1               0.004341         0.004319                 0.003888
# mean_rouge2              0.023447         0.016886                 0.025835
# var_rouge2               0.001144         0.001000                 0.000804
# mean_rougeL              0.132892         0.108110                 0.151335
# var_rougeL               0.002422         0.002541                 0.002168
# mean_rougeLsum           0.132892         0.108110                 0.151335
# var_rougeLsum            0.002422         0.002541                 0.002168
#
#                 llama_7b_predictions  starling_predictions  yagpt_predictions  \
# mean_precision              0.617807              0.597878           0.622112
# var_precision               0.002890              0.002965           0.002084
# mean_recall                 0.716344              0.697020           0.705082
# var_recall                  0.002252              0.001594           0.002066
# mean_f1                     0.662422              0.642646           0.660237
# var_f1                      0.002046              0.001885           0.001643
# mean_rouge1                 0.184048              0.163554           0.173754
# var_rouge1                  0.005549              0.004344           0.003705
# mean_rouge2                 0.031596              0.022257           0.024918
# var_rouge2                  0.001282              0.000571           0.000626
# mean_rougeL                 0.142696              0.128820           0.142116
# var_rougeL                  0.003371              0.002317           0.002513
# mean_rougeLsum              0.142696              0.125516           0.106047
# var_rougeLsum               0.003371              0.002226           0.002010
#
#                 yagpt3_predictions
# mean_precision            0.609768
# var_precision             0.001972
# mean_recall               0.712831
# var_recall                0.002063
# mean_f1                   0.656557
# var_f1                    0.001592
# mean_rouge1               0.184505
# var_rouge1                0.004085
# mean_rouge2               0.035398
# var_rouge2                0.001011
# mean_rougeL               0.142395
# var_rougeL                0.002225
# mean_rougeLsum            0.133073
# var_rougeLsum             0.002081

# %%
summary_dataset.to_csv("summary_dataset_with_bertscore_bleu_rouge.csv", index=False)

# %% [markdown]
# ## METEOR

# %% [markdown]
# https://huggingface.co/spaces/evaluate-metric/meteor

# %%
import pandas as pd
summary_dataset = pd.read_csv("summary_dataset_with_bertscore_bleu_rouge.csv")
files = [
    "mbart_predictions.txt",
    "mt5_predictions.txt",
    "summarunner_predictions.txt",
    "llama_7b_predictions.csv",
    "starling_predictions.csv",
    "yagpt_predictions.csv",
    "yagpt3_predictions.csv"
]

# %%
summary_dataset.columns
# Out:
# Index(['Ind', 'title', 'text', 'summary', 'mbart_predictions',
#        'mt5_predictions', 'summarunner_predictions', 'mbart_predictions_bleu',
#        'mt5_predictions_bleu', 'summarunner_predictions_bleu',
#        'llama_7b_predictions', 'starling_predictions', 'yagpt_predictions',
#        'yagpt3_predictions', 'mbart_predictions_bertscore_precision',
#        'mbart_predictions_bertscore_recall', 'mbart_predictions_bertscore_f1',
#        'mt5_predictions_bertscore_precision',
#        'mt5_predictions_bertscore_recall', 'mt5_predictions_bertscore_f1',
#        'summarunner_predictions_bertscore_precision',
#        'summarunner_predictions_bertscore_recall',
#        'summarunner_predictions_bertscore_f1',
#        'llama_7b_predictions_bertscore_precision',
#        'llama_7b_predictions_bertscore_recall',
#        'llama_7b_predictions_bertscore_f1',
#        'starling_predictions_bertscore_precision',
#        'starling_predictions_bertscore_recall',
#        'starling_predictions_bertscore_f1',
#        'yagpt_predictions_bertscore_precision',
#        'yagpt_predictions_bertscore_recall', 'yagpt_predictions_bertscore_f1',
#        'yagpt3_predictions_bertscore_precision',
#        'yagpt3_predictions_bertscore_recall',
#        'yagpt3_predictions_bertscore_f1', 'mbart_predictions_bleu.1',
#        'mt5_predictions_bleu.1', 'summarunner_predictions_bleu.1',
#        'llama_7b_predictions_bleu', 'starling_predictions_bleu',
#        'yagpt_predictions_bleu', 'yagpt3_predictions_bleu',
#        'mbart_predictions_rouge1', 'mbart_predictions_rouge2',
#        'mbart_predictions_rougeL', 'mbart_predictions_rougeLsum',
#        'mt5_predictions_rouge1', 'mt5_predictions_rouge2',
#        'mt5_predictions_rougeL', 'mt5_predictions_rougeLsum',
#        'summarunner_predictions_rouge1', 'summarunner_predictions_rouge2',
#        'summarunner_predictions_rougeL', 'summarunner_predictions_rougeLsum',
#        'llama_7b_predictions_rouge1', 'llama_7b_predictions_rouge2',
#        'llama_7b_predictions_rougeL', 'llama_7b_predictions_rougeLsum',
#        'starling_predictions_rouge1', 'starling_predictions_rouge2',
#        'starling_predictions_rougeL', 'starling_predictions_rougeLsum',
#        'yagpt_predictions_rouge1', 'yagpt_predictions_rouge2',
#        'yagpt_predictions_rougeL', 'yagpt_predictions_rougeLsum',
#        'yagpt3_predictions_rouge1', 'yagpt3_predictions_rouge2',
#        'yagpt3_predictions_rougeL', 'yagpt3_predictions_rougeLsum'],
#       dtype='object')

# %%
len(summary_dataset)
# Out:
# 51

# %%
from tqdm import tqdm
from threading import Thread
from evaluate import load
import os, contextlib

import nltk
nltk.download('wordnet')


def calculate_meteor(result_list, predictions, references, thread_no, step):
    meteor = None
    # with open(os.devnull, 'w') as devnull:
    #     with contextlib.redirect_stdout(devnull), contextlib.redirect_stderr(devnull):
    
    meteor = load('meteor')
    index = thread_no
    disable_tqdm = (thread_no != 0)
    
    
    with tqdm(total=len(predictions), disable=disable_tqdm) as pbar:
        pbar.update(index)
        while index < len(predictions):
            result_list[index] = meteor.compute(predictions=[predictions[index]], references=[references[index]])
            index += step
            pbar.update(step)
    print(f"Thread {thread_no} finished")

results = {}
references = list(summary_dataset["summary"])
for filename in files:
    predictions_field = filename.split(".")[0]
    predictions = list(summary_dataset[predictions_field])
    results[predictions_field] = [0] * len(predictions)
    
    thread_num = 1
    thread_pool = []
    for thread in range(thread_num):
        thread_pool.append(Thread(target=calculate_meteor, args=[results[predictions_field], predictions, references, thread, thread_num], daemon=True))
        thread_pool[-1].start()

    for thread in range(thread_num):
        thread_pool[thread].join()
# Out:
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|██████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 59.82it/s]
# Thread 0 finished
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 523.03it/s]
# Thread 0 finished
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 464.33it/s]
# Thread 0 finished
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 350.18it/s]
# Thread 0 finished
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 336.63it/s]
# Thread 0 finished
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 366.60it/s]
# Thread 0 finished
# [nltk_data] Downloading package wordnet to /home/skatori/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/skatori/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/skatori/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 371.33it/s]
# Thread 0 finished

# %%
print(results)
# Out:
# {'mbart_predictions': [{'meteor': 0.047393364928909956}, {'meteor': 0.037220843672456566}, {'meteor': 0.0992}, {'meteor': 0.10309278350515465}, {'meteor': 0.10600706713780918}, {'meteor': 0.1471140603480656}, {'meteor': 0.13636363636363635}, {'meteor': 0.2321977705170094}, {'meteor': 0.09485094850948508}, {'meteor': 0.20855379188712522}, {'meteor': 0.06147540983606558}, {'meteor': 0.078125}, {'meteor': 0.1739130434782609}, {'meteor': 0.10101010101010102}, {'meteor': 0.09067357512953368}, {'meteor': 0.044642857142857144}, {'meteor': 0.1348314606741573}, {'meteor': 0.19230769230769232}, {'meteor': 0.11627906976744187}, {'meteor': 0.07425742574257424}, {'meteor': 0.1627006880733945}, {'meteor': 0.05115089514066496}, {'meteor': 0.09328358208955226}, {'meteor': 0.07481296758104737}, {'meteor': 0.1724726775956284}, {'meteor': 0.0909090909090909}, {'meteor': 0.06993006993006994}, {'meteor': 0.04464285714285715}, {'meteor': 0.021067415730337075}, {'meteor': 0.06726457399103139}, {'meteor': 0.17204301075268819}, {'meteor': 0.09828009828009829}, {'meteor': 0.1702145740386658}, {'meteor': 0.1388888888888889}, {'meteor': 0.12280701754385963}, {'meteor': 0.16129032258064516}, {'meteor': 0.14158202523853494}, {'meteor': 0.1079136690647482}, {'meteor': 0.10367047308319738}, {'meteor': 0.077720207253886}, {'meteor': 0.05154639175257733}, {'meteor': 0.16666666666666669}, {'meteor': 0.19682539682539685}, {'meteor': 0.07122507122507123}, {'meteor': 0.1332604470359572}, {'meteor': 0.36695447409733123}, {'meteor': 0.04960317460317461}, {'meteor': 0.322624650433122}, {'meteor': 0.10670731707317072}, {'meteor': 0.0209643605870021}, {'meteor': 0.16176470588235298}], 'mt5_predictions': [{'meteor': 0.03614457831325301}, {'meteor': 0.05}, {'meteor': 0.01358695652173913}, {'meteor': 0.051546391752577324}, {'meteor': 0.054945054945054944}, {'meteor': 0.0837887067395264}, {'meteor': 0.06756756756756756}, {'meteor': 0.030769230769230767}, {'meteor': 0.055096418732782364}, {'meteor': 0.059760956175298814}, {'meteor': 0.043668122270742356}, {'meteor': 0.04926108374384237}, {'meteor': 0.111044776119403}, {'meteor': 0.09900990099009903}, {'meteor': 0.043227665706051875}, {'meteor': 0.04838709677419355}, {'meteor': 0.05827505827505827}, {'meteor': 0.06607929515418502}, {'meteor': 0.13488247863247863}, {'meteor': 0.1297236322617033}, {'meteor': 0.0176678445229682}, {'meteor': 0.09789473684210526}, {'meteor': 0.10346378767431401}, {'meteor': 0.03826530612244898}, {'meteor': 0.1512163050624589}, {'meteor': 0.10869565217391304}, {'meteor': 0.0}, {'meteor': 0.015337423312883437}, {'meteor': 0.0352112676056338}, {'meteor': 0.06944444444444443}, {'meteor': 0.05924170616113744}, {'meteor': 0.01358695652173913}, {'meteor': 0.06160164271047227}, {'meteor': 0.024154589371980676}, {'meteor': 0.07662835249042146}, {'meteor': 0.048231511254019296}, {'meteor': 0.08264462809917354}, {'meteor': 0.08333333333333333}, {'meteor': 0.06337308347529812}, {'meteor': 0.04076086956521739}, {'meteor': 0.0909090909090909}, {'meteor': 0.06696428571428571}, {'meteor': 0.0546448087431694}, {'meteor': 0.08928571428571429}, {'meteor': 0.11112894166733531}, {'meteor': 0.4304127666104036}, {'meteor': 0.05905511811023623}, {'meteor': 0.03496503496503496}, {'meteor': 0.033003300330033}, {'meteor': 0.010582010582010585}, {'meteor': 0.03333333333333333}], 'summarunner_predictions': [{'meteor': 0.1815364387678437}, {'meteor': 0.18385953297195898}, {'meteor': 0.12195121951219512}, {'meteor': 0.22516048672990327}, {'meteor': 0.18237082066869303}, {'meteor': 0.11904761904761904}, {'meteor': 0.33484568806389836}, {'meteor': 0.12182539682539681}, {'meteor': 0.22255555555555556}, {'meteor': 0.10344827586206896}, {'meteor': 0.0784313725490196}, {'meteor': 0.13034611992945327}, {'meteor': 0.11869436201780414}, {'meteor': 0.2486127336448598}, {'meteor': 0.05665722379603399}, {'meteor': 0.1553672316384181}, {'meteor': 0.1002227171492205}, {'meteor': 0.2398523985239852}, {'meteor': 0.15435684647302902}, {'meteor ...

# %%
for key in results.keys():
    results[key] = {f"{key}_meteor": [val["meteor"] if not isinstance(val, int) else 0 for val in results[key]]}
    print(key, len(results[key]))
# Out:
# mbart_predictions 1
# mt5_predictions 1
# summarunner_predictions 1
# llama_7b_predictions 1
# starling_predictions 1
# yagpt_predictions 1
# yagpt3_predictions 1

# %%
new_data = {}
for data_key in results.keys():
    for metric_key in results[data_key].keys():
        if "hashcode" in metric_key:
            continue
        new_data[metric_key] = pd.Series(results[data_key][metric_key])
new_data_df = pd.DataFrame(new_data)
new_data_df.head()
# Out:
#    mbart_predictions_meteor  mt5_predictions_meteor  \
# 0                  0.047393                0.036145
# 1                  0.037221                0.050000
# 2                  0.099200                0.013587
# 3                  0.103093                0.051546
# 4                  0.106007                0.054945
#
#    summarunner_predictions_meteor  llama_7b_predictions_meteor  \
# 0                        0.181536                     0.182509
# 1                        0.183860                     0.165975
# 2                        0.121951                     0.192115
# 3                        0.225160                     0.174309
# 4                        0.182371                     0.241204
#
#    starling_predictions_meteor  yagpt_predictions_meteor  \
# 0                     0.115063                  0.231934
# 1                     0.170541                  0.162835
# 2                     0.143198                  0.194789
# 3                     0.226337                  0.250197
# 4                     0.163728                  0.169492
#
#    yagpt3_predictions_meteor
# 0                   0.204158
# 1                   0.169991
# 2                   0.199416
# 3                   0.104895
# 4                   0.171053

# %%
new_summary_dataset = pd.concat([summary_dataset, new_data_df.set_index(summary_dataset.index)], axis=1)
new_summary_dataset.head()
# Out:
#    Ind                              title  \
# 0  156  wikilingua_multilingual-val-36988
# 1  400  wikilingua_multilingual-val-37232
# 2  472  wikilingua_multilingual-val-37304
# 3  500  wikilingua_multilingual-val-37332
# 4  501  wikilingua_multilingual-val-37333
#
#                                                 text  \
# 0  Лучший путь поддержания здоровья зубов и предо...
# 1  Ваши руки - ваше сокровище, ухаживайте за ними...
# 2  Или поместите ее в посудомоечную машину. Когда...
# 3  Все люди видят сны, и часто не по одному за но...
# 4  . Прежде всего вам необходимо начинать поиски ...
#
#                                              summary  \
# 0  Чистите зубы и используйте зубную нить. Не заб...
# 1  Чрезмерный уход за руками. Не бросайте свою ос...
# 2  После еды сложите посуду в раковину и споласки...
# 3  Ведите дневник сновидений. Делайте записи в дн...
# 4  Найдите свое определение любви Учитывайте разн...
#
#                                    mbart_predictions  \
# 0  Российские стоматологи рассказали о том, как з...
# 1  На этой неделе мы расскажем о том, как правиль...
# 2  В сегодняшнем обзоре мы расскажем о том, как п...
# 3  В преддверии ночи, когда вы проснетесь из-за с...
# 4  В сегодняшнем материале мы поговорим о том, ка...
#
#                                      mt5_predictions  \
# 0  Существует множество способов защитить зубы от...
# 1  Если вы когда-нибудь станете топ моделью, то н...
# 2    Вы можете вывести пятна из стиральной машины.\n
# 3  Сношения во сне могут помочь вам лучше понимат...
# 4  Любовь - это явление, которое можно описать ка...
#
#                              summarunner_predictions  mbart_predictions_bleu  \
# 0  выберите синюю водолазку и темный блеск для гу...                0.017496
# 1  регулярно мажьте руки питательным кремом. если...                0.016922
# 2  когда вы заметите, что она заполнена, запустит...                0.023233
# 3  записывайте все мельчайшие детали, а также фик...                0.066542
# 4  в контексте романтической любви многие нередко...                0.051349
#
#    mt5_predictions_bleu  summarunner_predictions_bleu  ...  \
# 0              0.005383                      0.060654  ...
# 1              0.011950                      0.075167  ...
# 2              0.002937                      0.036801  ...
# 3              0.058565                      0.039209  ...
# 4              0.049504                      0.029521  ...
#
#   yagpt3_predictions_rouge2 yagpt3_predictions_rougeL  \
# 0                  0.034682                  0.182857
# 1                  0.033898                  0.150000
# 2                  0.020202                  0.178218
# 3                  0.000000                  0.074627
# 4                  0.012987                  0.115385
#
#   yagpt3_predictions_rougeLsum mbart_predictions_meteor  \
# 0                     0.125714                 0.047393
# 1                     0.083333                 0.037221
# 2                     0.217822                 0.099200
# 3                     0.059701                 0.103093
# 4                     0.128205                 0.106007
#
#    mt5_predictions_meteor  summarunner_predictions_meteor  \
# 0                0.036145                        0.181536
# 1                0.050000                        0.183860
# 2                0.013587                        0.121951
# 3                0.051546                        0.225160
# 4                0.054945                        0.182371
#
#    llama_7b_predictions_meteor  starling_predictions_meteor  \
# 0                     0.182509                     0.115063
# 1                     0.165975                     0.170541
# 2                     0.192115                     0.143198
# 3                     0.174309                     0.226337
# 4                     0.241204                     0.163728
#
#    yagpt_predictions_meteor  yagpt3_predictions_meteor
# 0                  0.231934                   0.204158
# 1                  0.162835                   0.169991
# 2                  0.194789                   0.199416
# 3                  0.250197                   0.104895
# 4                  0.169492                   0.171053
#
# [5 rows x 77 columns]

# %%
summary_dataset = pd.DataFrame(new_summary_dataset)
del new_summary_dataset

# %%
summary_dataset.head()
# Out:
#    Ind                              title  \
# 0  156  wikilingua_multilingual-val-36988
# 1  400  wikilingua_multilingual-val-37232
# 2  472  wikilingua_multilingual-val-37304
# 3  500  wikilingua_multilingual-val-37332
# 4  501  wikilingua_multilingual-val-37333
#
#                                                 text  \
# 0  Лучший путь поддержания здоровья зубов и предо...
# 1  Ваши руки - ваше сокровище, ухаживайте за ними...
# 2  Или поместите ее в посудомоечную машину. Когда...
# 3  Все люди видят сны, и часто не по одному за но...
# 4  . Прежде всего вам необходимо начинать поиски ...
#
#                                              summary  \
# 0  Чистите зубы и используйте зубную нить. Не заб...
# 1  Чрезмерный уход за руками. Не бросайте свою ос...
# 2  После еды сложите посуду в раковину и споласки...
# 3  Ведите дневник сновидений. Делайте записи в дн...
# 4  Найдите свое определение любви Учитывайте разн...
#
#                                    mbart_predictions  \
# 0  Российские стоматологи рассказали о том, как з...
# 1  На этой неделе мы расскажем о том, как правиль...
# 2  В сегодняшнем обзоре мы расскажем о том, как п...
# 3  В преддверии ночи, когда вы проснетесь из-за с...
# 4  В сегодняшнем материале мы поговорим о том, ка...
#
#                                      mt5_predictions  \
# 0  Существует множество способов защитить зубы от...
# 1  Если вы когда-нибудь станете топ моделью, то н...
# 2    Вы можете вывести пятна из стиральной машины.\n
# 3  Сношения во сне могут помочь вам лучше понимат...
# 4  Любовь - это явление, которое можно описать ка...
#
#                              summarunner_predictions  mbart_predictions_bleu  \
# 0  выберите синюю водолазку и темный блеск для гу...                0.017496
# 1  регулярно мажьте руки питательным кремом. если...                0.016922
# 2  когда вы заметите, что она заполнена, запустит...                0.023233
# 3  записывайте все мельчайшие детали, а также фик...                0.066542
# 4  в контексте романтической любви многие нередко...                0.051349
#
#    mt5_predictions_bleu  summarunner_predictions_bleu  ...  \
# 0              0.005383                      0.060654  ...
# 1              0.011950                      0.075167  ...
# 2              0.002937                      0.036801  ...
# 3              0.058565                      0.039209  ...
# 4              0.049504                      0.029521  ...
#
#   yagpt3_predictions_rouge2 yagpt3_predictions_rougeL  \
# 0                  0.034682                  0.182857
# 1                  0.033898                  0.150000
# 2                  0.020202                  0.178218
# 3                  0.000000                  0.074627
# 4                  0.012987                  0.115385
#
#   yagpt3_predictions_rougeLsum mbart_predictions_meteor  \
# 0                     0.125714                 0.047393
# 1                     0.083333                 0.037221
# 2                     0.217822                 0.099200
# 3                     0.059701                 0.103093
# 4                     0.128205                 0.106007
#
#    mt5_predictions_meteor  summarunner_predictions_meteor  \
# 0                0.036145                        0.181536
# 1                0.050000                        0.183860
# 2                0.013587                        0.121951
# 3                0.051546                        0.225160
# 4                0.054945                        0.182371
#
#    llama_7b_predictions_meteor  starling_predictions_meteor  \
# 0                     0.182509                     0.115063
# 1                     0.165975                     0.170541
# 2                     0.192115                     0.143198
# 3                     0.174309                     0.226337
# 4                     0.241204                     0.163728
#
#    yagpt_predictions_meteor  yagpt3_predictions_meteor
# 0                  0.231934                   0.204158
# 1                  0.162835                   0.169991
# 2                  0.194789                   0.199416
# 3                  0.250197                   0.104895
# 4                  0.169492                   0.171053
#
# [5 rows x 77 columns]

# %% [markdown]
# Посчитаем статистики для представления о качестве датасета

# %%
from collections import defaultdict

score_stats = defaultdict(dict) if (not "score_stats" in locals() and not "score_stats" in globals()) else score_stats
for filename in files:
    predictions_field = filename.split(".")[0]
    score_stats[predictions_field].update({f"meteor": sum(results[predictions_field][f"{predictions_field}_meteor"]) / len(results[predictions_field][f"{predictions_field}_meteor"])})

# %%
stats_pd = pd.DataFrame(score_stats)

# %%
stats_pd.head(len(stats_pd))
# Out:
#                 mbart_predictions  mt5_predictions  summarunner_predictions  \
# mean_precision           0.613628         0.622904                 0.620263
# var_precision            0.002562         0.002883                 0.002443
# mean_recall              0.645983         0.596817                 0.666155
# var_recall               0.002007         0.001237                 0.001324
# mean_f1                  0.627817         0.608340                 0.641129
# var_f1                   0.001482         0.001345                 0.001276
# mean_rouge1              0.171170         0.121155                 0.188155
# var_rouge1               0.004341         0.004319                 0.003888
# mean_rouge2              0.023447         0.016886                 0.025835
# var_rouge2               0.001144         0.001000                 0.000804
# mean_rougeL              0.132892         0.108110                 0.151335
# var_rougeL               0.002422         0.002541                 0.002168
# mean_rougeLsum           0.132892         0.108110                 0.151335
# var_rougeLsum            0.002422         0.002541                 0.002168
# meteor                   0.119025         0.068467                 0.141537
#
#                 llama_7b_predictions  starling_predictions  yagpt_predictions  \
# mean_precision              0.617807              0.597878           0.622112
# var_precision               0.002890              0.002965           0.002084
# mean_recall                 0.716344              0.697020           0.705082
# var_recall                  0.002252              0.001594           0.002066
# mean_f1                     0.662422              0.642646           0.660237
# var_f1                      0.002046              0.001885           0.001643
# mean_rouge1                 0.184048              0.163554           0.173754
# var_rouge1                  0.005549              0.004344           0.003705
# mean_rouge2                 0.031596              0.022257           0.024918
# var_rouge2                  0.001282              0.000571           0.000626
# mean_rougeL                 0.142696              0.128820           0.142116
# var_rougeL                  0.003371              0.002317           0.002513
# mean_rougeLsum              0.142696              0.125516           0.106047
# var_rougeLsum               0.003371              0.002226           0.002010
# meteor                      0.185103              0.162675           0.183992
#
#                 yagpt3_predictions
# mean_precision            0.609768
# var_precision             0.001972
# mean_recall               0.712831
# var_recall                0.002063
# mean_f1                   0.656557
# var_f1                    0.001592
# mean_rouge1               0.184505
# var_rouge1                0.004085
# mean_rouge2               0.035398
# var_rouge2                0.001011
# mean_rougeL               0.142395
# var_rougeL                0.002225
# mean_rougeLsum            0.133073
# var_rougeLsum             0.002081
# meteor                    0.199865

# %%
summary_dataset.to_csv("summary_dataset_with_bertscore_bleu_rouge_meteor.csv", index=False)

# %%
summary_dataset = summary_dataset.head(35)

# %%
summary_dataset.to_csv("summary_dataset_with_bertscore_bleu_rouge_meteor.csv", index=False)

# %%
res = {}
for column in summary_dataset.columns:
    if "bleu" in column:
        res[column] = summary_dataset.loc[:, column].mean()

# %%
res
# Out:
# {'mbart_predictions_bleu': 0.0461162148004562,
#  'mt5_predictions_bleu': 0.04063504403212619,
#  'summarunner_predictions_bleu': 0.04393171673480969,
#  'mbart_predictions_bleu.1': 0.0461162148004562,
#  'mt5_predictions_bleu.1': 0.04063504403212619,
#  'summarunner_predictions_bleu.1': 0.04393171673480969,
#  'llama_7b_predictions_bleu': 0.03097015985650897,
#  'starling_predictions_bleu': 0.024204768855108062,
#  'yagpt_predictions_bleu': 0.024437143160110992,
#  'yagpt3_predictions_bleu': 0.028146147471788834}
