# %% [markdown]
# # Data for researchers

# %%
import pandas as pd
summary_dataset = pd.read_csv("summary_dataset_with_bertscore_rouge_meteor.csv")

# %%
summary_dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                title  \
# 0  В Германии объяснили упоминание имени Путина н...
# 1  Делегации Израиля и США прибыли в ОАЭ для обсу...
# 2  Оппозиция Белоруссии объявила о создании новой...
# 3  Россия считает крайне опасными действия США на...
# 4  В России вступил в силу закон о внесудебном ба...
#
#                                                 text  \
# 0  На этих выходных в Берлине прошли крупные акци...
# 1  Высокопоставленная американская и израильская ...
# 2  Одна из руководителей Координационного совета ...
# 3  Россия считает действия ВС США во время учений...
# 4  С 1 сентября в России вступают в силу поправки...
#
#                                              summary  \
# 0  Протестующие против антикоронавирусных мер нем...
# 1  Делегации Израиля и США прилетели в ОАЭ, где о...
# 2  Белорусская оппозиция в лице экс-кандидата в п...
# 3  Действия американских ВС в Эстонии во время уч...
# 4  Поправки в российский закон «О банкротстве» вс...
#
#                                    mbart_predictions  \
# 0  В Берлине прошли массовые акции протеста проти...
# 1  Высокопоставленная американская и израильская ...
# 2  Экс-кандидат в президенты Белоруссии Виктор Ба...
# 3  Россия считает действия ВС США во время учений...
# 4  С 1 сентября в России вступают в силу поправки...
#
#                                      mt5_predictions  \
# 0  В Берлине в субботу прошли массовые акции прот...
# 1  США и Израиль подписали историческое соглашени...
# 2  Координационный совет оппозиции Белоруссии объ...
# 3  Российское посольство считает, что действия ам...
# 4  С 1 сентября в России вступают в силу поправки...
#
#                              summarunner_predictions  \
# 0  на этих выходных в берлине прошли крупные акци...
# 1  высокопоставленная американская и израильская ...
# 2  одна из руководителей координационного совета ...
# 3  россия считает действия вс сша во время учений...
# 4  с 1 сентября в россии вступают в силу поправки...
#
#    mbart_predictions_bertscore_precision  mbart_predictions_bertscore_recall  \
# 0                               0.711897                            0.733298
# 1                               0.727948                            0.682448
# 2                               0.690570                            0.726228
# 3                               0.692291                            0.760886
# 4                               0.714218                            0.854085
#
#    ...  mt5_predictions_rouge2  mt5_predictions_rougeL  \
# 0  ...                0.050000                0.146341
# 1  ...                0.048193                0.164706
# 2  ...                0.035088                0.135593
# 3  ...                0.090909                0.176471
# 4  ...                0.422535                0.465753
#
#    mt5_predictions_rougeLsum  summarunner_predictions_rouge1  \
# 0                   0.146341                        0.272727
# 1                   0.164706                        0.222222
# 2                   0.135593                        0.306306
# 3                   0.176471                        0.346457
# 4                   0.465753                        0.391304
#
#    summarunner_predictions_rouge2  summarunner_predictions_rougeL  \
# 0                        0.092593                        0.181818
# 1                        0.034783                        0.153846
# 2                        0.110092                        0.252252
# 3                        0.128000                        0.267717
# 4                        0.220588                        0.289855
#
#    summarunner_predictions_rougeLsum  mbart_predictions_meteor  \
# 0                           0.181818                  0.327036
# 1                           0.153846                  0.155565
# 2                           0.252252                  0.332507
# 3                           0.267717                  0.399261
# 4                           0.289855                  0.601744
#
#    mt5_predictions_meteor  summarunner_predictions_meteor
# 0                0.209577                        0.298614
# 1                0.087664                        0.140027
# 2                0.069983                        0.336473
# 3                0.186599                        0.404262
# 4                0.576856                        0.570060
#
# [5 rows x 32 columns]

# %%
summary_dataset.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'title', 'text', 'summary',
#        'mbart_predictions', 'mt5_predictions', 'summarunner_predictions',
#        'mbart_predictions_bertscore_precision',
#        'mbart_predictions_bertscore_recall', 'mbart_predictions_bertscore_f1',
#        'mt5_predictions_bertscore_precision',
#        'mt5_predictions_bertscore_recall', 'mt5_predictions_bertscore_f1',
#        'summarunner_predictions_bertscore_precision',
#        'summarunner_predictions_bertscore_recall',
#        'summarunner_predictions_bertscore_f1', 'mbart_predictions_rouge1',
#        'mbart_predictions_rouge2', 'mbart_predictions_rougeL',
#        'mbart_predictions_rougeLsum', 'mt5_predictions_rouge1',
#        'mt5_predictions_rouge2', 'mt5_predictions_rougeL',
#        'mt5_predictions_rougeLsum', 'summarunner_predictions_rouge1',
#        'summarunner_predictions_rouge2', 'summarunner_predictions_rougeL',
#        'summarunner_predictions_rougeLsum', 'mbart_predictions_meteor',
#        'mt5_predictions_meteor', 'summarunner_predictions_meteor'],
#       dtype='object')

# %%
summary_dataset = summary_dataset.rename(columns={"Unnamed: 0": "Ind"})

# %%
summary_dataset.columns
# Out:
# Index(['Unnamed: 0.1', 'Ind', 'title', 'text', 'summary', 'mbart_predictions',
#        'mt5_predictions', 'summarunner_predictions',
#        'mbart_predictions_bertscore_precision',
#        'mbart_predictions_bertscore_recall', 'mbart_predictions_bertscore_f1',
#        'mt5_predictions_bertscore_precision',
#        'mt5_predictions_bertscore_recall', 'mt5_predictions_bertscore_f1',
#        'summarunner_predictions_bertscore_precision',
#        'summarunner_predictions_bertscore_recall',
#        'summarunner_predictions_bertscore_f1', 'mbart_predictions_rouge1',
#        'mbart_predictions_rouge2', 'mbart_predictions_rougeL',
#        'mbart_predictions_rougeLsum', 'mt5_predictions_rouge1',
#        'mt5_predictions_rouge2', 'mt5_predictions_rougeL',
#        'mt5_predictions_rougeLsum', 'summarunner_predictions_rouge1',
#        'summarunner_predictions_rouge2', 'summarunner_predictions_rougeL',
#        'summarunner_predictions_rougeLsum', 'mbart_predictions_meteor',
#        'mt5_predictions_meteor', 'summarunner_predictions_meteor'],
#       dtype='object')

# %%
summary_dataset.head()
# Out:
#    Unnamed: 0.1  Ind                                              title  \
# 0             0    0  В Германии объяснили упоминание имени Путина н...
# 1             1    1  Делегации Израиля и США прибыли в ОАЭ для обсу...
# 2             2    2  Оппозиция Белоруссии объявила о создании новой...
# 3             3    3  Россия считает крайне опасными действия США на...
# 4             4    4  В России вступил в силу закон о внесудебном ба...
#
#                                                 text  \
# 0  На этих выходных в Берлине прошли крупные акци...
# 1  Высокопоставленная американская и израильская ...
# 2  Одна из руководителей Координационного совета ...
# 3  Россия считает действия ВС США во время учений...
# 4  С 1 сентября в России вступают в силу поправки...
#
#                                              summary  \
# 0  Протестующие против антикоронавирусных мер нем...
# 1  Делегации Израиля и США прилетели в ОАЭ, где о...
# 2  Белорусская оппозиция в лице экс-кандидата в п...
# 3  Действия американских ВС в Эстонии во время уч...
# 4  Поправки в российский закон «О банкротстве» вс...
#
#                                    mbart_predictions  \
# 0  В Берлине прошли массовые акции протеста проти...
# 1  Высокопоставленная американская и израильская ...
# 2  Экс-кандидат в президенты Белоруссии Виктор Ба...
# 3  Россия считает действия ВС США во время учений...
# 4  С 1 сентября в России вступают в силу поправки...
#
#                                      mt5_predictions  \
# 0  В Берлине в субботу прошли массовые акции прот...
# 1  США и Израиль подписали историческое соглашени...
# 2  Координационный совет оппозиции Белоруссии объ...
# 3  Российское посольство считает, что действия ам...
# 4  С 1 сентября в России вступают в силу поправки...
#
#                              summarunner_predictions  \
# 0  на этих выходных в берлине прошли крупные акци...
# 1  высокопоставленная американская и израильская ...
# 2  одна из руководителей координационного совета ...
# 3  россия считает действия вс сша во время учений...
# 4  с 1 сентября в россии вступают в силу поправки...
#
#    mbart_predictions_bertscore_precision  mbart_predictions_bertscore_recall  \
# 0                               0.711897                            0.733298
# 1                               0.727948                            0.682448
# 2                               0.690570                            0.726228
# 3                               0.692291                            0.760886
# 4                               0.714218                            0.854085
#
#    ...  mt5_predictions_rouge2  mt5_predictions_rougeL  \
# 0  ...                0.050000                0.146341
# 1  ...                0.048193                0.164706
# 2  ...                0.035088                0.135593
# 3  ...                0.090909                0.176471
# 4  ...                0.422535                0.465753
#
#    mt5_predictions_rougeLsum  summarunner_predictions_rouge1  \
# 0                   0.146341                        0.272727
# 1                   0.164706                        0.222222
# 2                   0.135593                        0.306306
# 3                   0.176471                        0.346457
# 4                   0.465753                        0.391304
#
#    summarunner_predictions_rouge2  summarunner_predictions_rougeL  \
# 0                        0.092593                        0.181818
# 1                        0.034783                        0.153846
# 2                        0.110092                        0.252252
# 3                        0.128000                        0.267717
# 4                        0.220588                        0.289855
#
#    summarunner_predictions_rougeLsum  mbart_predictions_meteor  \
# 0                           0.181818                  0.327036
# 1                           0.153846                  0.155565
# 2                           0.252252                  0.332507
# 3                           0.267717                  0.399261
# 4                           0.289855                  0.601744
#
#    mt5_predictions_meteor  summarunner_predictions_meteor
# 0                0.209577                        0.298614
# 1                0.087664                        0.140027
# 2                0.069983                        0.336473
# 3                0.186599                        0.404262
# 4                0.576856                        0.570060
#
# [5 rows x 32 columns]

# %%
index = "Ind"
title = "title"
article = "text"
ground_truth = "summary"

files = [
    f"{ground_truth}.txt", # Dummy for summary field
    "mbart_predictions.txt",
    "mt5_predictions.txt",
    "summarunner_predictions.txt",
]
summaries_fields = []
metrics = [
    "Актуальность",
    "Последовательность",
    "Беглость",
    "Согласованность",
]

for file in files:
    model_name = file.split(".")[0]
    summaries_fields.append(model_name)
    for metric in metrics:
        summaries_fields.append(f"{model_name}_{metric}")
    summaries_fields.append(f"{model_name}_Комментарий")

# %%
summary_dataset = summary_dataset.reindex(columns = [index, article, *summaries_fields])

# %%
summary_dataset.head()
# Out:
#    Ind                                               text  \
# 0    0  На этих выходных в Берлине прошли крупные акци...
# 1    1  Высокопоставленная американская и израильская ...
# 2    2  Одна из руководителей Координационного совета ...
# 3    3  Россия считает действия ВС США во время учений...
# 4    4  С 1 сентября в России вступают в силу поправки...
#
#                                              summary  summary_Актуальность  \
# 0  Протестующие против антикоронавирусных мер нем...                   NaN
# 1  Делегации Израиля и США прилетели в ОАЭ, где о...                   NaN
# 2  Белорусская оппозиция в лице экс-кандидата в п...                   NaN
# 3  Действия американских ВС в Эстонии во время уч...                   NaN
# 4  Поправки в российский закон «О банкротстве» вс...                   NaN
#
#    summary_Последовательность  summary_Беглость  summary_Согласованность  \
# 0                         NaN               NaN                      NaN
# 1                         NaN               NaN                      NaN
# 2                         NaN               NaN                      NaN
# 3                         NaN               NaN                      NaN
# 4                         NaN               NaN                      NaN
#
#    summary_Комментарий                                  mbart_predictions  \
# 0                  NaN  В Берлине прошли массовые акции протеста проти...
# 1                  NaN  Высокопоставленная американская и израильская ...
# 2                  NaN  Экс-кандидат в президенты Белоруссии Виктор Ба...
# 3                  NaN  Россия считает действия ВС США во время учений...
# 4                  NaN  С 1 сентября в России вступают в силу поправки...
#
#    mbart_predictions_Актуальность  ...  mt5_predictions_Последовательность  \
# 0                             NaN  ...                                 NaN
# 1                             NaN  ...                                 NaN
# 2                             NaN  ...                                 NaN
# 3                             NaN  ...                                 NaN
# 4                             NaN  ...                                 NaN
#
#    mt5_predictions_Беглость  mt5_predictions_Согласованность  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
#
#    mt5_predictions_Комментарий  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                              summarunner_predictions  \
# 0  на этих выходных в берлине прошли крупные акци...
# 1  высокопоставленная американская и израильская ...
# 2  одна из руководителей координационного совета ...
# 3  россия считает действия вс сша во время учений...
# 4  с 1 сентября в россии вступают в силу поправки...
#
#    summarunner_predictions_Актуальность  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    summarunner_predictions_Последовательность  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    summarunner_predictions_Беглость  summarunner_predictions_Согласованность  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    summarunner_predictions_Комментарий
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 26 columns]

# %%
import random

random.seed(42)
indices_for_evaluation = random.sample(range(0, len(summary_dataset)), 100)

# %%
indices_for_evaluation = sorted(indices_for_evaluation)

# %%
print(indices_for_evaluation[:5])
# Out:
# [53, 204, 217, 244, 260]

# %%
summary_dataset = summary_dataset[summary_dataset["Ind"].isin(indices_for_evaluation)]

# %%
summary_dataset.head()
# Out:
#      Ind                                               text  \
# 53    53  Постоянно включенный Bluetooth на смартфоне гр...
# 204  204  Китайское издание Sina высоко оценило новый ро...
# 217  217  8 сентября в Японии официально стартовала изби...
# 244  244  Член президиума координационного совета оппози...
# 260  260  Аналитики Deutsche Bank обнародовали исследова...
#
#                                                summary  summary_Актуальность  \
# 53   Активированный в смартфоне Bluetooth может пре...                   NaN
# 204  Новый российский боевой железнодорожный ракетн...                   NaN
# 217  Генеральный секретарь кабинета министров Япони...                   NaN
# 244  Члена президиума оппозиционного Координационно...                   NaN
# 260  В истории человечества наступает эпоха беспоря...                   NaN
#
#      summary_Последовательность  summary_Беглость  summary_Согласованность  \
# 53                          NaN               NaN                      NaN
# 204                         NaN               NaN                      NaN
# 217                         NaN               NaN                      NaN
# 244                         NaN               NaN                      NaN
# 260                         NaN               NaN                      NaN
#
#      summary_Комментарий                                  mbart_predictions  \
# 53                   NaN  Постоянно включенный Bluetooth на смартфоне гр...
# 204                  NaN  Китайское издание Sina высоко оценило новый ро...
# 217                  NaN  В Японии официально стартовала избирательная к...
# 244                  NaN  Член президиума координационного совета оппози...
# 260                  NaN  В 2020 году в мире наступит новая эпоха беспор...
#
#      mbart_predictions_Актуальность  ...  mt5_predictions_Последовательность  \
# 53                              NaN  ...                                 NaN
# 204                             NaN  ...                                 NaN
# 217                             NaN  ...                                 NaN
# 244                             NaN  ...                                 NaN
# 260                             NaN  ...                                 NaN
#
#      mt5_predictions_Беглость  mt5_predictions_Согласованность  \
# 53                        NaN                              NaN
# 204                       NaN                              NaN
# 217                       NaN                              NaN
# 244                       NaN                              NaN
# 260                       NaN                              NaN
#
#      mt5_predictions_Комментарий  \
# 53                           NaN
# 204                          NaN
# 217                          NaN
# 244                          NaN
# 260                          NaN
#
#                                summarunner_predictions  \
# 53   постоянно включенный bluetooth на смартфоне гр...
# 204  китайское издание sina высоко оценило новый ро...
# 217  8 сентября в японии официально стартовала изби...
# 244  член президиума координационного совета оппози...
# 260  аналитики deutsche bank обнародовали исследова...
#
#      summarunner_predictions_Актуальность  \
# 53                                    NaN
# 204                                   NaN
# 217                                   NaN
# 244                                   NaN
# 260                                   NaN
#
#      summarunner_predictions_Последовательность  \
# 53                                          NaN
# 204                                         NaN
# 217                                         NaN
# 244                                         NaN
# 260                                         NaN
#
#      summarunner_predictions_Беглость  \
# 53                                NaN
# 204                               NaN
# 217                               NaN
# 244                               NaN
# 260                               NaN
#
#      summarunner_predictions_Согласованность  \
# 53                                       NaN
# 204                                      NaN
# 217                                      NaN
# 244                                      NaN
# 260                                      NaN
#
#      summarunner_predictions_Комментарий
# 53                                   NaN
# 204                                  NaN
# 217                                  NaN
# 244                                  NaN
# 260                                  NaN
#
# [5 rows x 26 columns]

# %%
summary_dataset.to_csv("summary_dataset_for_expert_evaluation.csv", index=False)

# %% [markdown]
# ## Join llm data

# %%
summary_files = [
    "llama_7b_predictions.csv",
    "starling_predictions.csv",
    "yagpt_predictions.csv",
    "yagpt3_predictions.csv"
]

llm_data = pd.DataFrame()
for summary_file in summary_files:
    model_name = summary_file.split(".")[0]
    df = pd.read_csv(summary_file)[[model_name]]
    llm_data = pd.concat([llm_data, df], axis=1)

llm_data.head()
# Out:
#                                 llama_7b_predictions  \
# 0  Bluetooth постоянно включен, это опасно, так к...
# 1  Китайское издание Sina высоко оценило новый ро...
# 2  8 сентября в Японии началась избирательная кам...
# 3  Мария Колесникова, член президиума координацио...
# 4  Аналитики Deutsche Bank предсказали наступлени...
#
#                                 starling_predictions  \
# 0  Постоянно включенный Bluetooth может создавать...
# 1  Китайский издание Sina высоко оценило новый ро...
# 2  Всего три кандидата — Есихидэ Суга, Сигэру Иси...
# 3  Мария Колесникова, член президиума координацио...
# 4  Аналитики Deutsche Bank предполагают, что 2020...
#
#                                    yagpt_predictions  \
# 0  - Постоянно включенный Bluetooth на смартфоне ...
# 1  К сожалению, я не могу ничего сказать об этом....
# 2  К сожалению, я не могу ничего сказать об этом....
# 3  - Член президиума координационного совета оппо...
# 4  - Аналитики Deutsche Bank предсказали наступле...
#
#                                   yagpt3_predictions
# 0  Доцент кафедры информатики РЭУ им. Плеханова А...
# 1  К сожалению, я не могу ничего сказать об этом....
# 2  К сожалению, я не могу ничего сказать об этом....
# 3  Мария Колесникова, член президиума координацио...
# 4  Аналитики Deutsche Bank предсказали наступлени...

# %%
summary_dataset.head()
print(len(llm_data))
# Out:
# 100

# %%
summary_dataset = pd.concat([summary_dataset, llm_data.set_index(summary_dataset.index)], axis=1)

# %%
summary_dataset.head()
# Out:
#      Ind                                               text  \
# 53    53  Постоянно включенный Bluetooth на смартфоне гр...
# 204  204  Китайское издание Sina высоко оценило новый ро...
# 217  217  8 сентября в Японии официально стартовала изби...
# 244  244  Член президиума координационного совета оппози...
# 260  260  Аналитики Deutsche Bank обнародовали исследова...
#
#                                                summary  summary_Актуальность  \
# 53   Активированный в смартфоне Bluetooth может пре...                   NaN
# 204  Новый российский боевой железнодорожный ракетн...                   NaN
# 217  Генеральный секретарь кабинета министров Япони...                   NaN
# 244  Члена президиума оппозиционного Координационно...                   NaN
# 260  В истории человечества наступает эпоха беспоря...                   NaN
#
#      summary_Последовательность  summary_Беглость  summary_Согласованность  \
# 53                          NaN               NaN                      NaN
# 204                         NaN               NaN                      NaN
# 217                         NaN               NaN                      NaN
# 244                         NaN               NaN                      NaN
# 260                         NaN               NaN                      NaN
#
#      summary_Комментарий                                  mbart_predictions  \
# 53                   NaN  Постоянно включенный Bluetooth на смартфоне гр...
# 204                  NaN  Китайское издание Sina высоко оценило новый ро...
# 217                  NaN  В Японии официально стартовала избирательная к...
# 244                  NaN  Член президиума координационного совета оппози...
# 260                  NaN  В 2020 году в мире наступит новая эпоха беспор...
#
#      mbart_predictions_Актуальность  ...  \
# 53                              NaN  ...
# 204                             NaN  ...
# 217                             NaN  ...
# 244                             NaN  ...
# 260                             NaN  ...
#
#                                summarunner_predictions  \
# 53   постоянно включенный bluetooth на смартфоне гр...
# 204  китайское издание sina высоко оценило новый ро...
# 217  8 сентября в японии официально стартовала изби...
# 244  член президиума координационного совета оппози...
# 260  аналитики deutsche bank обнародовали исследова...
#
#      summarunner_predictions_Актуальность  \
# 53                                    NaN
# 204                                   NaN
# 217                                   NaN
# 244                                   NaN
# 260                                   NaN
#
#      summarunner_predictions_Последовательность  \
# 53                                          NaN
# 204                                         NaN
# 217                                         NaN
# 244                                         NaN
# 260                                         NaN
#
#      summarunner_predictions_Беглость summarunner_predictions_Согласованность  \
# 53                                NaN                                     NaN
# 204                               NaN                                     NaN
# 217                               NaN                                     NaN
# 244                               NaN                                     NaN
# 260                               NaN                                     NaN
#
#      summarunner_predictions_Комментарий  \
# 53                                   NaN
# 204                                  NaN
# 217                                  NaN
# 244                                  NaN
# 260                                  NaN
#
#                                   llama_7b_predictions  \
# 53   Bluetooth постоянно включен, это опасно, так к...
# 204  Китайское издание Sina высоко оценило новый ро...
# 217  8 сентября в Японии началась избирательная кам...
# 244  Мария Колесникова, член президиума координацио...
# 260  Аналитики Deutsche Bank предсказали наступлени...
#
#                                   starling_predictions  \
# 53   Постоянно включенный Bluetooth может создавать...
# 204  Китайский издание Sina высоко оценило новый ро...
# 217  Всего три кандидата — Есихидэ Суга, Сигэру Иси...
# 244  Мария Колесникова, член президиума координацио...
# 260  Аналитики Deutsche Bank предполагают, что 2020...
#
#                                      yagpt_predictions  \
# 53   - Постоянно включенный Bluetooth на смартфоне ...
# 204  К сожалению, я не могу ничего сказать об этом....
# 217  К сожалению, я не могу ничего сказать об этом....
# 244  - Член президиума координационного совета оппо...
# 260  - Аналитики Deutsche Bank предсказали наступле...
#
#                                     yagpt3_predictions
# 53   Доцент кафедры информатики РЭУ им. Плеханова А...
# 204  К сожалению, я не могу ничего сказать об этом....
# 217  К сожалению, я не могу ничего сказать об этом....
# 244  Мария Колесникова, член президиума координацио...
# 260  Аналитики Deutsche Bank предсказали наступлени...
#
# [5 rows x 30 columns]

# %%
index = "Ind"
title = "title"
article = "text"
ground_truth = "summary"

files = [
    f"{ground_truth}.txt", # Dummy for summary field
    "mbart_predictions.txt",
    "mt5_predictions.txt",
    "summarunner_predictions.txt",
] + summary_files
summaries_fields = []
metrics = [
    "Актуальность",
    "Последовательность",
    "Беглость",
    "Согласованность",
]

for file in files:
    model_name = file.split(".")[0]
    summaries_fields.append(model_name)
    for metric in metrics:
        summaries_fields.append(f"{model_name}_{metric}")
    summaries_fields.append(f"{model_name}_Комментарий")

# %%
summary_dataset = summary_dataset.reindex(columns = [index, article, *summaries_fields])

# %%
summary_dataset.head()
# Out:
#      Ind                                               text  \
# 53    53  Постоянно включенный Bluetooth на смартфоне гр...
# 204  204  Китайское издание Sina высоко оценило новый ро...
# 217  217  8 сентября в Японии официально стартовала изби...
# 244  244  Член президиума координационного совета оппози...
# 260  260  Аналитики Deutsche Bank обнародовали исследова...
#
#                                                summary  summary_Актуальность  \
# 53   Активированный в смартфоне Bluetooth может пре...                   NaN
# 204  Новый российский боевой железнодорожный ракетн...                   NaN
# 217  Генеральный секретарь кабинета министров Япони...                   NaN
# 244  Члена президиума оппозиционного Координационно...                   NaN
# 260  В истории человечества наступает эпоха беспоря...                   NaN
#
#      summary_Последовательность  summary_Беглость  summary_Согласованность  \
# 53                          NaN               NaN                      NaN
# 204                         NaN               NaN                      NaN
# 217                         NaN               NaN                      NaN
# 244                         NaN               NaN                      NaN
# 260                         NaN               NaN                      NaN
#
#      summary_Комментарий                                  mbart_predictions  \
# 53                   NaN  Постоянно включенный Bluetooth на смартфоне гр...
# 204                  NaN  Китайское издание Sina высоко оценило новый ро...
# 217                  NaN  В Японии официально стартовала избирательная к...
# 244                  NaN  Член президиума координационного совета оппози...
# 260                  NaN  В 2020 году в мире наступит новая эпоха беспор...
#
#      mbart_predictions_Актуальность  ...  \
# 53                              NaN  ...
# 204                             NaN  ...
# 217                             NaN  ...
# 244                             NaN  ...
# 260                             NaN  ...
#
#      yagpt_predictions_Последовательность  yagpt_predictions_Беглость  \
# 53                                    NaN                         NaN
# 204                                   NaN                         NaN
# 217                                   NaN                         NaN
# 244                                   NaN                         NaN
# 260                                   NaN                         NaN
#
#      yagpt_predictions_Согласованность  yagpt_predictions_Комментарий  \
# 53                                 NaN                            NaN
# 204                                NaN                            NaN
# 217                                NaN                            NaN
# 244                                NaN                            NaN
# 260                                NaN                            NaN
#
#                                     yagpt3_predictions  \
# 53   Доцент кафедры информатики РЭУ им. Плеханова А...
# 204  К сожалению, я не могу ничего сказать об этом....
# 217  К сожалению, я не могу ничего сказать об этом....
# 244  Мария Колесникова, член президиума координацио...
# 260  Аналитики Deutsche Bank предсказали наступлени...
#
#      yagpt3_predictions_Актуальность  yagpt3_predictions_Последовательность  \
# 53                               NaN                                    NaN
# 204                              NaN                                    NaN
# 217                              NaN                                    NaN
# 244                              NaN                                    NaN
# 260                              NaN                                    NaN
#
#      yagpt3_predictions_Беглость  yagpt3_predictions_Согласованность  \
# 53                           NaN                                 NaN
# 204                          NaN                                 NaN
# 217                          NaN                                 NaN
# 244                          NaN                                 NaN
# 260                          NaN                                 NaN
#
#      yagpt3_predictions_Комментарий
# 53                              NaN
# 204                             NaN
# 217                             NaN
# 244                             NaN
# 260                             NaN
#
# [5 rows x 50 columns]

# %%
summary_dataset.to_csv("summary_dataset_for_expert_evaluation_with_llm.csv", index=False)

# %% [markdown]
# ## Remove invalid

# %%
summary_dataset = summary_dataset.loc[summary_dataset['yagpt_predictions'] != "К сожалению, я не могу ничего сказать об этом. Давайте сменим тему?"]

# %%
print(len(summary_dataset))
# Out:
# 65

# %%
summary_dataset.to_csv("summary_dataset_for_expert_evaluation_with_llm_cleaned.csv", index=False)
